# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“TIPE DATA DAN VARIABEL”**
#
# **Disusun Oleh :**
#
# **Humaira Zahratul 'Aini**
#
# **2611531010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="image\logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h2 align="center">KATA PENGANTAR</h2>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Tipe Data dan Variabel pada Python yang telah dilaksanakan sebagai pertemuan untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan jenis-jenis tipe data, penggunaan variabel, serta pendeklarasian nilai dalam bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar tipe data dan variabel serta pemanfaatannya dalam menyelesaikan masalah pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# <div align="right">
#
# Padang, 2026
#
# <br><br><br>
#
# **Humaira Zahratul 'Aini**
# 2611531010
#
# </div>

# %% [markdown]
# <h2 align="center">
# BAB I
#
# PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Bahasa pemrograman Python merupakan salah satu bahasa pemrograman tingkat tinggi yang populer dan banyak digunakan karena sintaksisnya yang sederhana serta mudah dipahami. Dalam proses pemograman, penyimpanan dan manipulasi data merupakan aspek paling mendasar yang harus dikuasai oleh seorang pemrogram.
#
# Untuk mengelola data tersebut, program membutuhkan sarana penyimpanan sementara di memori komputer yang dikenal sebagai variabel. Setiap variabel menyimpan nilai dengan jenis atau tipe data tertentu, seperti bilangan bulat (integer), bilangan desimal (float), teks (string), nilai kebenaran (boolean), hingga bilangan kompleks (complex). Pemahaman yang mendalam mengenai deklarasi variabel, pemrosesan tipe data, konversi data, serta penggunaan konstanta dan fungsi input/output sangat penting agar program dapat berjalan dengan akurat, efisien, dan bebas dari error. Oleh karena itu, praktikum mengenai tipe data dan variabel ini dilaksanakan sebagai landasan awal dalam menguasai konsep dasar pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Mengetahui dan memahami konsep dasar variabel serta cara mendeklarasikannya dalam bahasa pemrograman Python.
#
# 2. Mengidentifikasi dan menerapkan berbagai jenis tipe data dasar dalam Python, seperti integer, float, string, boolean, dan complex.
#
# 3. Memahami penggunaan fungsi input() untuk menerima masukan data interaktif dari pengguna dan fungsi print() untuk menampilkan luaran.
#
# 4. Memahami proses konversi tipe data (type casting) serta penggunaan konstanta dalam perhitungan matematis sederhana.
#
# ## 1.3 Manfaat
# 1. Menambah pengalaman mahasiswa dalam membuat serta menjalankan program Python.
# 2. Meningkatkan keterampilan dalam menggunakan VS Code sebagai editor kode.
# 3. Memahami pemanfaatan GitHub untuk menyimpan dan mengatur kode program.
# 4. Membantu mahasiswa mengelola proyek pemrograman dengan lebih terorganisir.
# 5. Menjadi bekal awal untuk mempelajari dan mengembangkan proyek pemrograman berikutnya.

# %% [markdown]
# <h2 align="center">
# BAB II
#
# PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Pengolahan informasi di dalam program membutuhkan sarana penyimpanan dan pengelompokan jenis nilai. Variabel berperan sebagai wadah penampung atau referensi nilai di dalam memori komputer. Pembuatan variabel pada Python dilakukan dengan menetapkan nilai menggunakan tanda sama dengan (=). Sementara itu, tipe data berfungsi menetapkan sifat dan jenis nilai yang dimuat oleh variabel tersebut sehingga sistem dapat memprosesnya dengan tepat.
#
# Python memiliki beberapa tipe data standar yang sering digunakan dalam penyusunan program, antara lain:
#
# 1. Integer (int): Digunakan untuk menampung data berupa angka atau bilangan bulat tanpa nilai pecah, seperti 10, 25, maupun bilangan negatif seperti -5.
#
# 2. Float (float): Digunakan untuk menyimpan nilai angka pecahan atau desimal, seperti 3.14, 10.5, dan 0.75.
#
# 3. Complex (complex): Tipe data khusus untuk merepresentasikan bilangan kompleks yang terdiri atas komponen real serta imajiner, contohnya 3+2j.
#
# 4. String (str): Digunakan untuk menampung data teks atau deretan karakter. Penulisan nilai string diapit oleh tanda petik, seperti "Python" atau "Informatika".
#
# 5. Boolean (bool): Tipe data logika yang hanya memiliki dua pilihan nilai kebenaran, yaitu True (benar) dan False (salah). Tipe ini umumnya dipakai untuk mengevaluasi suatu kondisi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Numerik_2611531010"

# %%
#create a variable with numeric type value.
a=1010
print("The type of variable having value",a,"is",type(a))

#create a variable with float value.
b=10.2345
print("The type of variable having value",b,"is",type(b))

#create a variable with complex value.
c=100+3j
print("The type of variable having value",c,"is",type(c))

# %% [markdown]
# ```text
# The type of variable having value 1010 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# **Penjelasan :**
#
# 1. `a = 1010` digunakan untuk membuat variabel `a` yang bernilai angka bulat (*integer*).
# 2. `b = 10.2345` digunakan untuk membuat variabel `b` yang bernilai angka desimal (*float*).
# 3. `c = 100+3j` digunakan untuk membuat variabel `c` yang bernilai bilangan kompleks (*complex*).
# 4. `type()` digunakan untuk mengecek dan menampilkan tipe data dari suatu variabel.
# 5. `print()` digunakan untuk menampilkan teks, nilai variabel, serta tipe data variabel ke layar.

# %% [markdown]
# ### 2.2.2 Program "String_2611531010"

# %%
#Ganti programnya dengan data masing2
nama = "Humaira"
jenis_kelamin = 'P'
alamat = """
    Tarok Dipo
    kec. Guguak Panjang
    kota Bukittinggi
"""
agama = 'islam'
print("Nama saya adalah: ", nama)
print("Jenis kelamin saya adalah: ", jenis_kelamin)
print("Alamat saya adalah: ",alamat)
print("Agama saya adalah: ",agama)

# %% [markdown]
# ```text
# Nama saya adalah:  Humaira
# Jenis kelamin saya adalah:  P
# Alamat saya adalah:
#     Tarok Dipo
#     kec. Guguak Panjang
#     kota Bukittinggi
#
# Agama saya adalah:  islam

# %% [markdown]
# **Penjelasan:**
#
# 1. Variabel `nama` dan `agama` menyimpan data berupa teks biasa menggunakan tanda petik tunggal atau ganda.
# 2. Variabel `jenis_kelamin` menyimpan satu karakter teks untuk menyatakan jenis kelamin.
# 3. Variabel `alamat` menggunakan tanda petik tiga (`"""`) agar dapat menyimpan teks berbaris-baris sesuai format aslinya.
# 4. Fungsi `print()` digunakan untuk menampilkan keterangan beserta nilai dari masing-masing variabel ke layar.

# %% [markdown]
# ### 2.2.3 Program "Boolean_2611531010"

# %%
#Deklarasi variabel dengan tipe data Boolean
is_lulus = True
is_cumlaude = True

# Menggunakan Boolean
nilai = 85
batas_lulus = 75

# Menentukan nilai Boolean dari kondisi 
status_kelulusan = nilai >= batas_lulus  #Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai:", nilai)
print("Apakah Lulus?:", status_kelulusan)
if is_lulus and is_cumlaude:
    print("Selamat, Anda lulus dengan predikat cumlaude!")

# %% [markdown]
# ```text
# === Check Kelulusan ===
# Nilai: 85
# Apakah Lulus?: True
# Selamat, Anda lulus dengan predikat cumlaude!

# %% [markdown]
# **Penjelasan:**
#
# 1. Variabel `is_lulus` dan `is_cumlaude` menyimpan nilai bertipe data Boolean, yaitu `True`.
# 2. Variabel `status_kelulusan` menyimpan hasil dari kondisi `nilai >= batas_lulus`, yang menghasilkan nilai `True` karena angka 85 lebih besar dari 75.
# 3. Pengondisian `if` menggunakan operator logika `and` untuk memastikan kedua variabel (`is_lulus` dan `is_cumlaude`) bernilai `True` sebelum menjalankan baris kode di dalamnya.
# 4. Fungsi `print()` menampilkan teks judul, isi nilai variabel, hasil pengecekan Boolean, serta pesan selamat ke layar.

# %% [markdown]
# ### 2.2.4 Program "Input_2611531010"

# %%
# Nama program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit nim terakhir contoh: panjang_1010
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukkan nila panjang dann lebar persegi panjang.
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_1234 = input('Masukkan nilai panjang')
lebar_1234 = input('Masukkan nilai lebar')
luas_1234 = int(panjang_1234) * int(lebar_1234)
print("Luas =", luas_1234)

# %% [markdown]
# ```text
# Masukkan nilai panjang 10
# Masukkan nilai lebar 5
# Luas = 50

# %% [markdown]
# **Penjelasan:**
#
# 1. Fungsi `input()` digunakan untuk menerima masukan nilai panjang dan lebar dari pengguna secara interaktif melalui layar terminal.
# 2. Fungsi `int()` mengonversi tipe data masukan yang semula berbentuk teks (*string*) menjadi bilangan bulat (*integer*) agar dapat dihitung secara matematis.
# 3. Perkalian antara variabel `panjang_1234` dan `lebar_1234` dilakukan untuk menghitung nilai luas persegi panjang yang kemudian disimpan ke dalam variabel `luas_1234`.
# 4. Fungsi `print()` menampilkan hasil perhitungan nilai luas ke layar.

# %% [markdown]
# ### 2.2.5 Program "Konstanta_2611531010"

# %%
# Program ini menggunakan konstanta untul menghitung luas lingkaran
# nama variabel ditambah 4 digit nim terakhir contoh: jari_1010

from typing import Final
PI: Final = 3.14
print("pi: %f" %(PI))
jari_1234 = float(input('Masukkan nilai jari-jari: '))
luas_1234 = PI * jari_1234 * jari_1234
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" %(jari_1234, luas_1234))

# %% [markdown]
# ```text
# pi: 3.140000
# Masukkan nilai jari-jari: 7
# Luas lingkaran dengan jari-jari 7.00 adalah 153.86

# %% [markdown]
# **Penjelasan:**
#
# 1. Modul `typing.Final` digunakan untuk menandai variabel `PI` sebagai nilai konstanta yang bernilai tetap, yaitu `3.14`.
# 2. Fungsi `input()` yang dibungkus `float()` mengambil masukan jari-jari dari pengguna dan langsung mengonversinya menjadi bilangan desimal.
# 3. Rumus `PI * jari_1234 * jari_1234` digunakan untuk menghitung nilai luas lingkaran yang kemudian disimpan ke variabel `luas_1234`.
# 4. Fungsi `print()` menggunakan format penulisan `%f` untuk menampilkan nilai desimal, serta `%.2f` untuk membatasi tampilan angka di belakang koma menjadi dua digit.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal prak2.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas2_2611531010"

# %%
from typing import Final

# 1. Deklarasi Konstanta (Ganti 1234 dengan 4 digit terakhir NIM kamu)
BATAS_LULUS_1234: Final[float] = 75.0

# 2. Input Data (String & Type Casting Numerik)
print("=== SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===")
nama_1234 = input("Masukkan Nama Mahasiswa: ")
jk_1234 = input("Masukkan Jenis Kelamin (L/P): ")

print("Masukkan Alamat Domisili (Tekan Enter, lalu ketik baris berikutnya):")
alamat_1234 = f"""{input("  Baris 1: ")}
{input("  Baris 2: ")}"""

umur_1234 = int(input("Masukkan Umur: "))
skor_1234 = float(input("Masukkan Skor Tes Awal: "))

# Tipe Data Complex & Boolean Verification
token_1234 = 100 + 3j
status_lulus_1234 = skor_1234 >= BATAS_LULUS_1234

# 3. Output Data dan Pengecekan Tipe Data
print("\n=== DATA PRAKTIKAN & HASIL PEMERIKSAAN ===")
print(f"Nama Mahasiswa  : {nama_1234} | Tipe: {type(nama_1234)}")
print(f"Jenis Kelamin   : {jk_1234} | Tipe: {type(jk_1234)}")
print(f"Alamat Domisili :\n{alamat_1234} | Tipe: {type(alamat_1234)}")
print(f"Umur            : {umur_1234} tahun | Tipe: {type(umur_1234)}")
print(f"Skor Tes Awal   : {skor_1234} | Tipe: {type(skor_1234)}")
print(f"ID Token Sinyal : {token_1234} | Tipe: {type(token_1234)}")

print("\n=== STATUS KELULUSAN PRAKTIKUM ===")
print(f"Batas Minimum Nilai  : {BATAS_LULUS_1234}")
print(f"Apakah Dinyatakan Lulus?: {status_lulus_1234} | Tipe: {type(status_lulus_1234)}")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="image/output tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program ini dirancang untuk mencatat data identitas praktikan baru, mengolah tipe data numerik dan teks, serta melakukan verifikasi status kelulusan praktikan secara otomatis. Seluruh alur program mengintegrasikan konsep variabel, konstanta, type casting, tipe data dasar Python, operator logika, hingga pemeriksaan tipe data melalui fungsi type().

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilaksanakan, dapat ditarik beberapa kesimpulan sebagai berikut:
#
# 1. Variabel dan Tipe Data: Variabel berfungsi sebagai tempat penyimpanan nilai di dalam memori komputer yang dibuat menggunakan operator penugasan (=). Tipe data menentukan jenis nilai yang disimpan, meliputi int (bilangan bulat), float (bilangan desimal), complex (bilangan kompleks), str (teks/karakter), dan bool (nilai kebenaran True/False).
#
# 2. Konstanta: Dalam Python, konstanta diwakili dengan penamaan variabel menggunakan huruf kapital (seperti PI) atau penanda Final untuk menandakan bahwa nilainya bersifat tetap dan tidak dimaksudkan untuk diubah selama program berjalan.
#
# 3. Input, Output, dan Konversi Data: Fungsi input() digunakan untuk menerima masukan pengguna yang secara otomatis bertipe str, sehingga memerlukan konversi tipe data (type casting) seperti int() atau float() jika ingin digunakan dalam perhitungan matematis. Sementara itu, fungsi print() berfungsi untuk menampilkan hasil proses atau nilai variabel ke layar terminal.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] FreeCodeCamp. (2026). Python for Beginners – Full Course and Interactive Tutorials. FreeCodeCamp.org. https://www.freecodecamp.org/learn/scientific-computing-with-python/
#
# [2] GitHub, Inc. (2026). GitHub Docs: Getting Started with Git and Version Control for Academic Projects. GitHub Documentation. https://docs.github.com/en/get-started
#
# [3] Matthes, E. (2023). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (3rd ed.). No Starch Press.
#
# [4] Python Software Foundation. (2026). The Python Standard Library: Built-in Types & Input/Output. Python Documentation. https://docs.python.org/3/library/stdtypes.html
#
# [5] W3Schools. (2026). Python Data Types and Variables Tutorial. W3Schools Online Web Tutorials. https://www.w3schools.com/python/
