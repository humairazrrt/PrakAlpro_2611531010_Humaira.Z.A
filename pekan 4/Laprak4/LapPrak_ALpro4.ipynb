# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“CONDITIONAL PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Humaira Zahratul 'Aini**
#
# **2611531010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h2 align="center">KATA PENGANTAR</h2>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Conditional pada Python yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan penerapan percabangan (conditional statement).
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep Conditional Python serta pemanfaatannya dalam menyelesaikan masalah pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# <div align="right">
#
# Padang, 2026
#
# <br>
#
# **Humaira Zahratul 'Aini**
# 2611531010
#
# </div>

# %% [markdown]
# <h2 align="center">
# BAB I
#
# PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Bahasa pemrograman Python menyediakan berbagai struktur kontrol alur (control flow) untuk mengatur urutan eksekusi instruksi berdasarkan pengujian kondisi logika (boolean expression). Dalam praktikum Pekan 4 Praktikum Struktur Data, fokus pembelajaran diarahkan pada penerapan percabangan (conditional statement).   Percabangan memungkinkan program membuat keputusan secara otomatis saat program berjalan (runtime). Implementasinya mencakup berbagai bentuk skenario, mulai dari keputusan tunggal (if), dua pilihan alternatif (if-else), evaluasi bertingkat beruntun (if-elif-else), hingga pengecekan kondisi mandiri yang dapat saling menumpuk (multi-if). Selain itu, sejak Python 3.10 diperkenalkan fitur match-case sebagai cara yang lebih terstruktur untuk mencocokkan nilai variabel terhadap sejumlah pilihan pasti. Pemahaman mendalam mengenai perbedaan alur eksekusi dari masing-masing struktur ini menjadi fondasi utama dalam merancang perangkat lunak yang andal, efisien, dan bebas bug.
# ## 1.2 Tujuan
# 1. Memahami mekanisme alur eksekusi pernyataan kondisional if, if-else, dan if-elif-else pada Python.
# 2. Menganalisis perbedaan alur eksekusi antara struktur bertingkat (if-elif-else) dengan struktur independen (multi-if).
# 3. Menerapkan operator logika (and, not) serta perbandingan (>, >=, <, <=, ==, !=) dalam menyusun syarat kelayakan program.
# 4. Mengimplementasikan struktur pattern matching (match-case) untuk penanganan kasus pilihan diskrit.
# 5. Menyelesaikan 7 kasus latihan praktikum dengan standarisasi penamaan variabel menggunakan akhiran NIM (1010).
# ## 1.3 Manfaat
# 1. Mampu menentukan struktur percabangan yang paling efisien sesuai dengan kebutuhan logika bisnis program.
# 2. Dapat menghindari kesalahan logika (logic errors) saat menangani kondisi beruntun maupun akumulasi diskon.
# 3. Tersusunnya dokumentasi akademis yang sistematis mengenai hasil praktikum percabangan Python.

# %% [markdown]
# <h2 align="center">
# BAB II
#
# PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Conditional merupakan struktur dalam Python yang digunakan untuk mengontrol alur eksekusi perintah berdasarkan hasil evaluasi kriteria tertentu. Melalui conditional, program mengevaluasi nilai kebenaran (*True* atau *False*) untuk menentukan apakah suatu instruksi akan dijalankan atau dilewati.
#
# 1. if
# Digunakan untuk mengeksekusi suatu perintah hanya ketika syarat yang diberikan bernilai benar (*True*). Jika syarat tidak terpenuhi, perintah di dalamnya diabaikan. Contohnya pada `if1_2611531010.py`, program mengecek `if ipk_1010 > 2.75:` untuk mencetak status lulus.
#
# 2. if-else
# Digunakan ketika program menghadapi dua alur pilihan. Perintah pada blok `if` dijalankan jika kondisi bernilai benar, sedangkan jika salah, program akan mengeksekusi perintah pada blok `else`. Contohnya pada `if2_2611531010.py`, jika IPK memenuhi syarat dicetak lulus, jika tidak maka alur dialihkan ke `else` untuk mencetak tidak lulus.
#
# 3. if-elif-else
# Digunakan saat terdapat lebih dari dua kondisi yang perlu diuji secara bertingkat. Python memeriksa setiap kondisi secara berurutan dari atas ke bawah hingga menemukan kondisi pertama yang bernilai benar. Contohnya pada `nilai_2611531010.py` untuk mengonversi nilai angka ke huruf A, B, C, D, atau E, serta pada `if_elif_else1_2611531010.py` untuk mengecek kualifikasi umur dan SIM.
#
# 4. multi-if
# Terdiri dari beberapa blok `if` terpisah yang berdiri mandiri tanpa terikat satu sama lain. Setiap kondisi diuji secara independen sehingga beberapa perintah dapat dieksekusi bersamaan jika semua syaratnya benar. Contohnya pada `multi_if2_2611531010.py` untuk menghitung penumpukan diskon belanja dan `multi_if1_2611531010.py` untuk pengecekan syarat terpisah.
#
# 5. match-case
# Merupakan fitur *pattern matching* yang digunakan untuk mencocokkan nilai variabel terhadap daftar pilihan nilai pasti secara lebih rapi. Contohnya pada `match_case1_2611531010.py` yang mencocokkan angka bulan (1–12) langsung dengan nama bulannya.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if_elif_else1_2611531010.py"

# %%
# Buat file dengan nama proram if_elif_else1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_1010 = int(input("Input umur anda: "))
sim_1010 = input("Apakah Anda Sudah Punya Sim C: ") [0]

if umur_1010 >= 17 and sim_1010 == 'y':
    print("Anda Sudah Dewasa dan Boleh Bawa Motor")
elif umur_1010 >= 17 and sim_1010 != 'y':
    print("Anda Sudah Dewasa tetapi tidak boleh bawa motor")
elif umur_1010 < 17 and sim_1010 == 'y':
    print("Anda belum cukup umur punya SIM")
else: 
    print("Anda Belum Cukup Umur dan Tidak boleh bawa motor")
print("Program Selesai")

# %% [markdown]
# ```text
# Input umur anda: 18
# Apakah Anda Sudah Punya Sim C: y
# Anda Sudah Dewasa dan Boleh Bawa Motor
# Program Selesai

# %% [markdown]
# **Penjelasan :**
#
# * Baris 1–4: Berisi komentar pendukung yang menjelaskan instruksi pembuatan file, aturan penamaan variabel dengan 4 digit terakhir NIM (`1010`), serta keterangan penggunaan fungsi `input()`.
# * Baris 6: Meminta masukan umur dari pengguna, mengonversinya menjadi tipe data integer (`int`), lalu menyimpannya ke variabel `umur_1010`.
# * Baris 7: Meminta masukan status kepemilikan SIM C. Penggunaan indeks `[0]` berfungsi mengambil karakter pertama dari input yang dimasukkan pengguna (misalnya jika menginput `"ya"`, yang diambil hanya huruf `'y'`).
# * Baris 9–10: Kondisi `if` pertama memeriksa apakah `umur_1010 >= 17` **dan** `sim_1010 == 'y'`. Jika keduanya bernilai `True`, program mencetak `"Anda Sudah Dewasa dan Boleh Bawa Motor"`.
# * Baris 11–12: Kondisi `elif` kedua memeriksa jika pengguna sudah dewasa (`umur_1010 >= 17`) tetapi tidak memiliki SIM C (`sim_1010 != 'y'`). Jika terpenuhi, program mencetak `"Anda Sudah Dewasa tetapi tidak boleh bawa motor"`.
# * Baris 13–14: Kondisi `elif` ketiga memeriksa jika pengguna belum cukup umur (`umur_1010 < 17`) tetapi mengklaim memiliki SIM C (`sim_1010 == 'y'`). Jika terpenuhi, program mencetak `"Anda belum cukup umur punya SIM"`.
# * Baris 15–16: Blok `else` menangani kondisi terakhir, yaitu pengguna belum cukup umur dan tidak memiliki SIM C. Program mencetak `"Anda Belum Cukup Umur dan Tidak boleh bawa motor"`.
# * Baris 17: Mencetak teks `"Program Selesai"` di luar struktur percabangan sebagai penanda bahwa eksekusi seluruh perintah telah selesai.

# %% [markdown]
# ### 2.2.2 Program "if1_2611531010.py"

# %%
# Buat file dengan nama proram if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_1010 = float(input("Input IPK Anda = "))

if ipk_1010 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_1010))
        
print("Program Selesai")

# %% [markdown]
# ```text
# Input IPK Anda = 3.89
# Anda Lulus Sangat Memuaskan dengan IPK 3.89
# Program Selesai

# %% [markdown]
# **Penjelasan:**
#
#
# * Baris 1–4: Berisi komentar yang menjelaskan instruksi pembuatan file, aturan penamaan variabel dengan 4 digit terakhir NIM (`1010`), serta penggunaan fungsi `input()`.
#
#
# * Baris 6: Meminta masukan nilai IPK dari pengguna, mengonversinya menjadi tipe data desimal (`float`), lalu menyimpannya ke dalam variabel `ipk_1010`.
#
#
# * Baris 8–9: Menguji kondisi `if` apakah nilai `ipk_1010` lebih dari `2.75`. Jika bernilai benar (`True`), program akan mencetak teks kelulusan beserta nilai IPK yang dikonversi ke string `str(ipk_1010)`. Jika salah (`False`), blok perintah ini diabaikan.
#
#
# * Baris 11: Baris di luar blok `if` yang mencetak kalimat `"Program Selesai"` sebagai penanda bahwa eksekusi program telah berakhir.

# %% [markdown]
# ### 2.2.3 Program "if2_2611531010.py"

# %%
# Buat file dengan nama proram if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_1010 = float(input("Input IPK Anda = "))

if ipk_1010 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_1010))
else:
    print("Anda tidak lulus")
print("Program Selesai")

# %% [markdown]
# ```text
# Input IPK Anda = 1.9
# Anda tidak lulus
# Program Selesai

# %% [markdown]
# **Penjelasan:**
#
#
# * Baris 1–4: Berisi komentar pendukung yang menjelaskan petunjuk pembuatan file, aturan penamaan variabel menggunakan 4 digit NIM terakhir (`1010`), serta keterangan penggunaan fungsi `input()`.
#
#
# * Baris 6: Meminta masukan nilai IPK dari pengguna, mengonversinya menjadi tipe data desimal (`float`), dan menyimpannya ke dalam variabel `ipk_1010`.
#
#
# * Baris 8–9: Kondisi `if` mengecek apakah `ipk_1010 > 2.75`. Jika bernilai benar (`True`), program mencetak kalimat kelulusan beserta nilai IPK yang dikonversi ke string `str(ipk_1010)`.
#
#
# * Baris 10–11: Blok `else` dijalankan apabila kondisi `if` bernilai salah (`False`), yaitu ketika IPK $\le 2.75$. Program akan mencetak pesan `"Anda tidak lulus"`.
#
#
# * Baris 12: Perintah di luar blok percabangan yang mencetak teks `"Program Selesai"` untuk menandai akhir eksekusi program.

# %% [markdown]
# ### 2.2.4 Program "match_case1_2611531010.py"

# %%
# Buat file dengan nama match_case1.py
# Buat program untuk kondisi if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1010
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_1010 = int(input("Masukkan angka bulan (1-12):"))

match bulan_1010:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")

# %% [markdown]
# ```text
# Masukkan angka bulan (1-12):8
# Agustus

# %% [markdown]
# Berikut penjelasan baris per baris untuk kode program `match_case1_2611531010.py`:
#
# * Baris 1–5: Berisi komentar pendukung yang menjelaskan petunjuk nama file, pembuatan program pencocokan pola, aturan penamaan variabel menggunakan 4 digit NIM terakhir (`1010`), serta fungsi program untuk mengonversi angka menjadi nama bulan.
#
#
# * Baris 7: Meminta masukan angka bulan dari pengguna, mengonversinya menjadi tipe data integer (`int`), dan menyimpannya ke dalam variabel `bulan_1010`.
#
#
# * Baris 9: Membuka struktur pengondisian `match` untuk mengevaluasi nilai variabel `bulan_1010`.
#
#
# * Baris 10–33: Berisi pilihan `case` dari `1` hingga `12`. Jika nilai `bulan_1010` cocok dengan salah satu angka tersebut, program mencetak nama bulan yang sesuai (misalnya `case 1:` mencetak `"Januari"`, `case 2:` mencetak `"Februari"`, hingga `case 12:` mencetak `"Desember"`).
#
#
# * Baris 34–35: Blok `case _:` berfungsi sebagai opsi default (*catch-all*). Jika pengguna memasukkan angka di luar rentang 1–12, program mencetak pesan `"Angka tidak valid"`.

# %% [markdown]
# ### 2.2.5 Program "multi_if1_2611531010.py"

# %%
# Buat file dengan nama proram multi_if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: umur_1234
# Program ini menggunakan fungsi input()

umur_1010 = int(input("Input umur anda: "))
sim_1010 = input("Apakah Anda Sudah Punya Sim C (y/t): ") [0]

if umur_1010 >= 17 and sim_1010 == 'y':
    print("Anda Sudah Dewasa dan Boleh Bawa Motor")
    
if umur_1010 >= 17 and sim_1010 != 'y':
   print("Anda Sudah Dewasa tetapi tidak boleh bawa motor")
   
if umur_1010 < 17  and sim_1010 == 'y' :
    print("Anda belum cukup umur punya SIM")
    
if umur_1010 <17 and sim_1010 != 'y':
    print("Anda belum cukup umur bawa motor")

# %% [markdown]
# ```text
# Input umur anda: 18
# Apakah Anda Sudah Punya Sim C (y/t): y
# Anda Sudah Dewasa dan Boleh Bawa Motor

# %% [markdown]
# **Penjelasan:**
#
# * Baris 1–4: Berisi komentar pendukung yang menjelaskan petunjuk nama file, aturan penamaan variabel dengan 4 digit NIM terakhir (`1010`), serta keterangan penggunaan fungsi `input()`.
#
#
# * Baris 6: Meminta masukan umur dari pengguna, mengonversinya menjadi tipe data integer (`int`), dan menyimpannya ke dalam variabel `umur_1010`.
#
#
# * Baris 7: Meminta masukan status SIM C. Penggunaan indeks `[0]` berfungsi mengambil karakter pertama dari teks yang diinput pengguna.
#
#
# * Baris 9–10: Pernyataan `if` pertama mengecek apakah `umur_1010 >= 17` **dan** `sim_1010 == 'y'`. Jika benar (`True`), program mencetak `"Anda Sudah Dewasa dan Boleh Bawa Motor"`.
#
#
# * Baris 12–13: Pernyataan `if` kedua secara terpisah mengecek apakah `umur_1010 >= 17` **dan** `sim_1010 != 'y'`. Jika benar (`True`), program mencetak `"Anda Sudah Dewasa tetapi tidak boleh bawa motor"`.
#
#
# * Baris 15–16: Pernyataan `if` ketiga mengecek apakah `umur_1010 < 17` **dan** `sim_1010 == 'y'`. Jika benar (`True`), program mencetak `"Anda belum cukup umur punya SIM"`.
#
#
# * Baris 18–19: Pernyataan `if` keempat mengecek apakah `umur_1010 < 17` **dan** `sim_1010 != 'y'`. Jika benar (`True`), program mencetak `"Anda belum cukup umur bawa motor"`.

# %% [markdown]
# ### 2.2.6 Program "multi_if2_2611531010.py"

# %%
# Buat file dengan nama proram multi_if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: total_belanja_1010
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

#Input dari user
total_belanja_1010 = float(input("Masukkan total belanja (Rp)"))

#Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_1010 = input("Apakah anda member? (y/t): ").strip().lower()
is_member_1010 = input_member_1010 in ["y","ya"]

#Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_1010 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_1010 = input_promo_1010 in ["y","ya"]

total_diskon_persen_1010 = 0

# Multi IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_1010 > 1000000:
    total_diskon_persen_1010 += 10 # Diskon belanja besar
    
if is_member_1010:
    total_diskon_persen_1010 += 5 # Diskon member
    
if kode_promo_valid_1010:
    total_diskon_persen_1010 += 15 # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_1010 = total_belanja_1010 * (total_diskon_persen_1010 / 100)
total_bayar_1010 = total_belanja_1010 - nominal_diskon_1010

# Output hasil perhitungan
print("\n--- Hasil Perhitungan Diskon ---")
print(f"Total Diskon : {total_diskon_persen_1010}% (Rp{nominal_diskon_1010:,.0f})")
print(f"Total Bayar  : Rp {total_bayar_1010:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_1010}%")
# Output Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, meber, dan kode promo valid

# %% [markdown]
# ```text
# Masukkan total belanja (Rp)35000
# Apakah anda member? (y/t): y
# Apakah kode promo valid? (y/t): y
#
# --- Hasil Perhitungan Diskon ---
# Total Diskon : 20% (Rp7,000)
# Total Bayar  : Rp 28,000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# **Penjelasan:**
#
#
# * Baris 1–5: Berisi komentar pendukung yang menjelaskan petunjuk nama file, aturan penamaan variabel dengan 4 digit NIM terakhir (`1010`), penggunaan fungsi `input()`, dan tujuan program untuk menghitung diskon belanja bertingkat.
# * Baris 8: Meminta masukan nominal total belanja dari pengguna, mengonversinya menjadi tipe data desimal (`float`), lalu menyimpannya ke dalam variabel `total_belanja_1010`.
# * Baris 11–12: Meminta masukan status *member*, kemudian metode `.strip().lower()` menghapus spasi liar serta mengubah huruf menjadi kecil. Ekspresi `in ["y","ya"]` akan menghasilkan nilai boolean `True` jika jawaban pengguna adalah `"y"` atau `"ya"`, lalu menyimpannya di variabel `is_member_1010`.
# * Baris 15–16: Meminta masukan validasi kode promo dengan perlakuan pembersihan teks yang sama, lalu menyimpan nilai boolean (`True`/`False`) ke dalam variabel `kode_promo_valid_1010`.
# * Baris 18: Menginisialisasi variabel akumulator `total_diskon_persen_1010` dengan nilai awal `0`.
# * Baris 23–24: Pernyataan `if` pertama memeriksa apakah `total_belanja_1010 > 1000000`. Jika benar, persentase diskon bertambah $10\%$ (`+= 10`).
# * Baris 26–27: Pernyataan `if` kedua secara terpisah memeriksa apakah `is_member_1010` bernilai `True`. Jika benar, persentase diskon bertambah $5\%$ (`+= 5`).
# * Baris 29–30: Pernyataan `if` ketiga memeriksa apakah `kode_promo_valid_1010` bernilai `True`. Jika benar, persentase diskon bertambah $15\%$ (`+= 15`).
# * Baris 33–34: Menghitung besarnya potongan harga dalam rupiah (`nominal_diskon_1010`) dan menghitung total tagihan akhir setelah dipotong diskon (`total_bayar_1010`).
# * Baris 37–41: Mencetak rincian hasil perhitungan diskon dan total pembayaran dengan format angka rupiah serta persentase akumulasi diskon yang didapat.

# %% [markdown]
# ### 2.2.7 Program "nilai_2611531010.py"

# %%
# Buat file dengan nama if_nim.py
# Buat program untuk kondisi if
# Nma variabel ditambah 4 digit nim terakhir contoh: ipk_1010
# Program konversi nilai angka menjadi huruf

nilai_1010 = int(input("Masukkan nilai angka = "))

if nilai_1010 >= 81:
    print("A")
elif nilai_1010 >= 70:
    print("B")
elif nilai_1010 >= 60:
    print("C")
elif nilai_1010 >= 50:
    print("D")
else:
    print("E")

# %% [markdown]
# ```text
# Masukkan nilai angka = 8
# E

# %% [markdown]
# **Penjelasan**
#
# * Baris 1–4: Berisi komentar pendukung yang menjelaskan petunjuk nama file, aturan penamaan variabel dengan 4 digit NIM terakhir (`1010`), serta tujuan program untuk mengonversi nilai angka menjadi nilai huruf.
# * Baris 6: Meminta masukan nilai angka dari pengguna, mengonversinya menjadi tipe data integer (`int`), lalu menyimpannya ke dalam variabel `nilai_1010`.
# * Baris 8–9: Kondisi `if` pertama memeriksa apakah `nilai_1010 >= 81`. Jika benar (`True`), program mencetak huruf `"A"`.
# * Baris 10–11: Kondisi `elif` kedua mengecek apakah `nilai_1010 >= 70`. Jika benar (nilai di antara 70–80), program mencetak huruf `"B"`.
# * Baris 12–13: Kondisi `elif` ketiga mengecek apakah `nilai_1010 >= 60`. Jika benar (nilai di antara 60–69), program mencetak huruf `"C"`.
# * Baris 14–15: Kondisi `elif` keempat mengecek apakah `nilai_1010 >= 50`. Jika benar (nilai di antara 50–59), program mencetak huruf `"D"`.
# * Baris 16–17: Blok `else` dijalankan apabila semua kondisi di atas bernilai salah (`False`), yaitu untuk nilai di bawah 50 (`nilai_1010 < 50`), lalu mencetak huruf `"E"`.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal prak4.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas4_2611531010"

# %%
# =========================================================
# SISTEM LOKET TERPADU & AUDIT TRANSAKSI EKSPEDISI WAHANA
# =========================================================

# Input Data Pengunjung & String Handling
nama_1010 = input("Masukkan Nama Pengunjung        : ")
umur_1010 = int(input("Input umur anda                 : "))

# mengambil karakter pertama dan diubah ke huruf kecil
sim_input_1010 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()
sim_1010 = sim_input_1010[0] if sim_input_1010 else "t"

# menampilkan pilihan paket wahana
print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

pilihan_paket_1010 = int(input("Masukkan nomor paket (1-5)      : "))
jumlah_tiket_1010 = int(input("Masukkan jumlah tiket           : "))

# penerapan IF tunggal untuk validasi kuota tiket
if jumlah_tiket_1010 <= 0: print("\n[Peringatan] Jumlah kuota tiket tidak valid!")

# input status member dan kode promo
is_member_input_1010 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_input_1010 = (input("Apakah kode promo valid? (y/t)  : ").strip().lower())

# inisialisasi variabel pendukung
nama_wahana_1010 = ""
harga_satuan_1010 = 0
valid_paket_1010 = True

# Pemilihan Wahana Menggunakan match-case (1-5 & default _)
match pilihan_paket_1010:
    case 1:
        nama_wahana_1010 = "Wahana Safari Rimba"
        harga_satuan_1010 = 50000
    case 2:
        nama_wahana_1010 = "Wahana Arung Jeram"
        harga_satuan_1010 = 75000
    case 3:
        nama_wahana_1010 = "Wahana Motor ATV Ekstrim"
        harga_satuan_1010 = 120000
    case 4:
        nama_wahana_1010 = "Wahana Roller Coaster Kilat"
        harga_satuan_1010 = 100000
    case 5:
        nama_wahana_1010 = "Wahana All-Access VIP"
        harga_satuan_1010 = 220000
    case _:
        print("\nPaket wahana tidak valid!")
        valid_paket_1010 = False

# Eksekusi sisa transaksi jika paket wahana valid
if valid_paket_1010:
    print("\n--- KELAYAKAN PENGENDARA WAHANA ---")

    # validasi Izin Kendali Wahana Menggunakan if - elif - else dan Operator Logika (and, !=)
    if pilihan_paket_1010 == 3:
        if umur_1010 >= 17 and sim_1010 == "y":
            print("Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.")
        elif umur_1010 >= 17 and sim_1010 != "y":
            print("Status Akses: Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
        elif umur_1010 < 17 and sim_1010 == "y":
            print("Status Akses: Identitas tidak valid: Belum cukup umur memiliki SIM.")
        else:
            print("Status Akses: Anda belum cukup umur dan tidak boleh bawa motor ATV.")
    else:
        if umur_1010 >= 10:
            print(f"Status Akses: Pengunjung memenuhi syarat usia untuk {nama_wahana_1010}.")
        else:
            print(f"Status Akses: Pengunjung belum cukup umur untuk {nama_wahana_1010}.")

    # Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah
    subtotal_1010 = harga_satuan_1010 * jumlah_tiket_1010
    total_diskon_persen_1010 = 0

    if subtotal_1010 >= 200000:
        total_diskon_persen_1010 += 10  # Diskon Belanja Besar

    if is_member_input_1010 in ["y", "ya"]:
        total_diskon_persen_1010 += 5  # Diskon Member

    if kode_promo_input_1010 in ["y", "ya"]:
        total_diskon_persen_1010 += 15  # Diskon Voucher Promo

    if jumlah_tiket_1010 >= 5:
        total_diskon_persen_1010 += 5  # Diskon Tambahan Rombongan

    # Evaluasi Kelulusan Audit & Rincian Pembayaran
    nominal_diskon_1010 = subtotal_1010 * (total_diskon_persen_1010 / 100)
    total_bayar_1010 = subtotal_1010 - nominal_diskon_1010

    print("\n--- Rincian Pembayaran ---")
    print(f"Subtotal Belanja : Rp {subtotal_1010:,.0f}")
    print(f"Total Diskon     : {total_diskon_persen_1010}% (Rp {nominal_diskon_1010:,.0f})")
    print(f"Total Bayar      : Rp {total_bayar_1010:,.0f}")

    if total_bayar_1010 > 300000:
        print("Catatan Layanan  : Selamat! Anda berhak mendapatkan Souvenir Gratis.")
    else:
        print("Catatan Layanan  : Terima kasih telah berkunjung.")

    print("Program Selesai")

# %% [markdown]
# ```text
# Masukkan Nama Pengunjung        : humaira
# Input umur anda                 : 18
# Apakah Anda Sudah Punya SIM C (y/t): y
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
# Masukkan nomor paket (1-5)      : 3
# Masukkan jumlah tiket           : 1
# Apakah Anda member? (y/t)       : y
# Apakah kode promo valid? (y/t)  : y
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 120,000
# Total Diskon     : 20% (Rp 24,000)
# Total Bayar      : Rp 96,000
# Catatan Layanan  : Terima kasih telah berkunjung.
# Program Selesai

# %% [markdown]
# **Penjelasan :**
#
# * **Baris 1**: Komentar pembuka berisi judul program.
# * **Baris 2**: Komentar keterangan modul praktikum.
# * **Baris 3**: Komentar pembatas berupa garis tanda sama dengan (`=`).
# * **Baris 4**: Baris kosong.
# * **Baris 5**: Komentar penanda bagian Input Data Pengunjung & String Handling.
# * **Baris 6**: Meminta masukan nama pengunjung dan menyimpannya ke variabel `nama_1010`.
# * **Baris 7**: Meminta masukan umur, mengonversinya ke `int`, dan menyimpannya ke variabel `umur_1010`.
# * **Baris 8**: Baris kosong.
# * **Baris 9**: Komentar proses pengambilan karakter pertama SIM C.
# * **Baris 10**: Meminta input status SIM C, menghapus spasi liar dengan `.strip()`, dan mengubah huruf menjadi kecil dengan `.lower()`.
# * **Baris 11**: Mengambil karakter pertama input SIM. Jika kosong, variabel `sim_1010` diisi nilai *default* `"t"`.
# * **Baris 12**: Baris kosong.
# * **Baris 13**: Komentar penanda bagian menampilkan menu wahana.
# * **Baris 14**: Mencetak judul menu pilihan paket wahana ke konsol.
# * **Baris 15**: Mencetak pilihan Paket 1 (Safari Rimba - Rp 50,000).
# * **Baris 16**: Mencetak pilihan Paket 2 (Arung Jeram - Rp 75,000).
# * **Baris 17**: Mencetak pilihan Paket 3 (Motor ATV Ekstrim - Rp 120,000).
# * **Baris 18**: Mencetak pilihan Paket 4 (Roller Coaster Kilat - Rp 100,000).
# * **Baris 19**: Mencetak pilihan Paket 5 (All-Access VIP - Rp 220,000).
# * **Baris 20**: Baris kosong.
# * **Baris 21**: Meminta masukan nomor paket wahana (1–5) dan menyimpannya ke variabel `pilihan_paket_1010`.
# * **Baris 22**: Meminta masukan jumlah tiket dan menyimpannya ke variabel `jumlah_tiket_1010`.
# * **Baris 23**: Baris kosong.
# * **Baris 24**: Komentar penanda validasi kuota tiket.
# * **Baris 25**: Menggunakan *if tunggal* untuk memeriksa apakah `jumlah_tiket_1010 <= 0` dan mencetak peringatan jika tidak valid.
# * **Baris 26**: Baris kosong.
# * **Baris 27**: Komentar penanda bagian input status member dan promo.
# * **Baris 28**: Meminta masukan status member, lalu merapikan teks dengan `.strip().lower()`.
# * **Baris 29**: Meminta masukan validitas kode promo, lalu merapikan teks dengan `.strip().lower()`.
# * **Baris 30**: Baris kosong.
# * **Baris 31**: Komentar penanda inisialisasi variabel pendukung.
# * **Baris 32**: Menginisialisasi variabel `nama_wahana_1010` dengan string kosong.
# * **Baris 33**: Menginisialisasi variabel `harga_satuan_1010` dengan nilai `0`.
# * **Baris 34**: Menginisialisasi variabel penanda `valid_paket_1010` dengan nilai `True`.
# * **Baris 35**: Baris kosong.
# * **Baris 36**: Komentar penanda struktur selection match-case.
# * **Baris 37**: Memulai struktur *match-case* berdasarkan nilai `pilihan_paket_1010`.
# * **Baris 38**: Kondisi `case 1` jika pengguna memilih Paket 1.
# * **Baris 39**: Mengisi variabel `nama_wahana_1010` dengan `"Wahana Safari Rimba"`.
# * **Baris 40**: Mengisi variabel `harga_satuan_1010` dengan nilai `50000`.
# * **Baris 41**: Kondisi `case 2` jika pengguna memilih Paket 2.
# * **Baris 42**: Mengisi variabel `nama_wahana_1010` dengan `"Wahana Arung Jeram"`.
# * **Baris 43**: Mengisi variabel `harga_satuan_1010` dengan nilai `75000`.
# * **Baris 44**: Kondisi `case 3` jika pengguna memilih Paket 3.
# * **Baris 45**: Mengisi variabel `nama_wahana_1010` dengan `"Wahana Motor ATV Ekstrim"`.
# * **Baris 46**: Mengisi variabel `harga_satuan_1010` dengan nilai `120000`.
# * **Baris 47**: Kondisi `case 4` jika pengguna memilih Paket 4.
# * **Baris 48**: Mengisi variabel `nama_wahana_1010` dengan `"Wahana Roller Coaster Kilat"`.
# * **Baris 49**: Mengisi variabel `harga_satuan_1010` dengan nilai `100000`.
# * **Baris 50**: Kondisi `case 5` jika pengguna memilih Paket 5.
# * **Baris 51**: Mengisi variabel `nama_wahana_1010` dengan `"Wahana All-Access VIP"`.
# * **Baris 52**: Mengisi variabel `harga_satuan_1010` dengan nilai `220000`.
# * **Baris 53**: Kondisi default `case _` jika nomor paket di luar 1–5.
# * **Baris 54**: Mencetak pesan error bahwa paket wahana tidak valid.
# * **Baris 55**: Mengubah status variabel penanda `valid_paket_1010` menjadi `False`.
# * **Baris 56**: Baris kosong.
# * **Baris 57**: Komentar penanda bagian eksekusi transaksi paket valid.
# * **Baris 58**: Memeriksa apakah status `valid_paket_1010` bernilai `True`.
# * **Baris 59**: Mencetak header pembatas bagian kelayakan pengendara wahana.
# * **Baris 60**: Baris kosong.
# * **Baris 61**: Komentar penanda validasi izin kendali wahana (if-elif-else & operator logika).
# * **Baris 62**: Memeriksa apakah pilihan paket adalah Paket 3 (Motor ATV Ekstrim).
# * **Baris 63**: Memeriksa jika umur $\ge 17$ tahun dan memiliki SIM C (`'y'`).
# * **Baris 64**: Mencetak status akses bahwa pengunjung boleh mengendarai ATV sendiri.
# * **Baris 65**: Memeriksa jika umur $\ge 17$ tahun tetapi tidak memiliki SIM C (`!= 'y'`).
# * **Baris 66**: Mencetak status akses bahwa pengunjung wajib didampingi instruktur.
# * **Baris 67**: Memeriksa jika umur $< 17$ tahun tetapi memilih memiliki SIM C.
# * **Baris 68**: Mencetak keterangan bahwa identitas SIM tidak valid.
# * **Baris 69**: Blok `else` jika tidak memenuhi kondisi di atas.
# * **Baris 70**: Mencetak status akses bahwa pengunjung belum cukup umur untuk membawa ATV.
# * **Baris 71**: Blok `else` untuk pilihan paket selain Paket 3.
# * **Baris 72**: Memeriksa apakah umur pengunjung $\ge 10$ tahun.
# * **Baris 73**: Mencetak status akses bahwa pengunjung memenuhi syarat usia wahana.
# * **Baris 74**: Blok `else` jika umur pengunjung $< 10$ tahun.
# * **Baris 75**: Mencetak status akses bahwa pengunjung belum cukup umur untuk wahana tersebut.
# * **Baris 76**: Baris kosong.
# * **Baris 77**: Komentar penanda akumulasi diskon bertingkat (Multi-IF Terpisah).
# * **Baris 78**: Menghitung subtotal belanja (`harga_satuan_1010 * jumlah_tiket_1010`).
# * **Baris 79**: Menginisialisasi variabel `total_diskon_persen_1010` dengan nilai `0`.
# * **Baris 80**: Baris kosong.
# * **Baris 81**: Memeriksa kondisi diskon 1 (apakah subtotal belanja $\ge$ Rp200.000).
# * **Baris 82**: Menambahkan persentase diskon sebesar `10`% (Diskon Belanja Besar).
# * **Baris 83**: Baris kosong.
# * **Baris 84**: Memeriksa kondisi diskon 2 (apakah status member berupa `'y'` atau `'ya'`).
# * **Baris 85**: Menambahkan persentase diskon sebesar `5`% (Diskon Member).
# * **Baris 86**: Baris kosong.
# * **Baris 87**: Memeriksa kondisi diskon 3 (apakah kode promo berupa `'y'` atau `'ya'`).
# * **Baris 88**: Menambahkan persentase diskon sebesar `15`% (Diskon Voucher Promo).
# * **Baris 89**: Baris kosong.
# * **Baris 90**: Memeriksa kondisi diskon 4 (apakah jumlah tiket $\ge 5$).
# * **Baris 91**: Menambahkan persentase diskon sebesar `5`% (Diskon Tambahan Rombongan).
# * **Baris 92**: Baris kosong.
# * **Baris 93**: Komentar penanda evaluasi kelulusan audit & rincian pembayaran.
# * **Baris 94**: Menghitung nominal Rupiah diskon berdasarkan persentase diskon yang diperoleh.
# * **Baris 95**: Menghitung total bayar bersih (`subtotal_1010 - nominal_diskon_1010`).
# * **Baris 96**: Baris kosong.
# * **Baris 97**: Mencetak header rincian pembayaran.
# * **Baris 98**: Mencetak nilai subtotal belanja menggunakan format desimal `:,.0f`.
# * **Baris 99**: Mencetak persentase dan nominal diskon menggunakan format desimal `:,.0f`.
# * **Baris 100**: Mencetak total bayar akhir menggunakan format desimal `:,.0f`.
# * **Baris 101**: Baris kosong.
# * **Baris 102**: Memeriksa apakah total bayar $> 300.000$ untuk evaluasi bonus audit.
# * **Baris 103**: Mencetak catatan layanan bahwa pengunjung berhak mendapatkan Souvenir Gratis.
# * **Baris 104**: Blok `else` jika total bayar $\le 300.000$.
# * **Baris 105**: Mencetak catatan layanan ucapan terima kasih standar dan pesan bahwa program selesai.

# %% [markdown]
# <h2 align="center">
# BAB III
#
# KESIMPULAN
#
# ##
# 1. Struktur Percabangan Dasar (if dan if-else): Pernyataan if tunggal berfungsi mengeksekusi instruksi hanya jika syarat bernilai True. Sementara itu, if-else memberikan opsi penanganan alternatif ketika kondisi utama bernilai False.
# 2. Evaluasi Bertingkat vs Independen (if-elif-else vs multi-if):
# * Struktur if-elif-else bekerja secara sekuensial interdependen; program akan berhenti mengevaluasi begitu menemukan kondisi pertama yang bernilai True (seperti pada konversi nilai angka ke huruf dan kualifikasi SIM).
# * Struktur multi-if bekerja secara independen di mana setiap pernyataan if diuji secara terpisah, sehingga memungkinkan adanya eksekusi bersamaan atau penumpukan logika (seperti pada akumulasi diskon belanja).
# 3. Pencocokan Pola (match-case): Struktur match-case terbukti lebih efisien dan rapi dibandingkan if-elif-else untuk penanganan kasus pilihan diskrit, seperti mengonversi angka bulan (1–12) menjadi nama bulan.
# 4. Penggunaan Operator: Kombinasi operator logika (and, not) serta operator perbandingan sangat krusial dalam menentukan kebenaran suatu kondisi kompleks pada alur program.

# %% [markdown]
# <h2 align="center">
# DAFTAR PUSTAKA
#
# ##
#
# [1]Downy, A. B. (2015). Think Python: How to Think Like a Computer Scientist (2nd ed.). O'Reilly Media.
#
# [2] Python Software Foundation. (2024). Python 3.12 Documentation: Control Flow Tools. Python.org. https://docs.python.org/3/tutorial/controlflow.html
#
# [3] Rossum, G. v., Drake, F. L., & FL, D. (2009). An Introduction to Python. Network Theory Ltd.
#
# [4] Sweigart, A. (2019). Automate the Boring Stuff with Python: Practical Programming for Total Beginners (2nd ed.). No Starch Press.
