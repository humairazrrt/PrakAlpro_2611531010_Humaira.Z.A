# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Humaira Zahratul 'Aini**
#
# **2611531010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h2 align="center">KATA PENGANTAR</h2>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Operator pada Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan operasi aritmatika, perbandingan, logika, dan penugasan dalam bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar operator Python serta pemanfaatannya dalam menyelesaikan masalah pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# <div align="right">
#
# Padang, 2026
#
# <br>
#
# **Humaira Zahratul 'Aini**
# 2611531010
#
# </div>

# %% [markdown]
# <h2 align="center">
# BAB I
#
# PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Bahasa pemrograman Python dikenal dengan kemudahan sintaksisnya dalam menangani berbagai macam logika instruksi dan pemrosesan data. Setelah memahami konsep dasar penyimpanan data dalam variabel, tahap krusial berikutnya dalam pembuatan program adalah manipulasi dan evaluasi data tersebut menggunakan operator.
#
# Operator merupakan simbol-simbol khusus yang digunakan untuk melakukan operasi tertentu terhadap satu atau lebih nilai (operan). Dalam Python, terdapat berbagai jenis operator yang mendukung pemrosesan data secara komprehensif, mulai dari pemrosesan perhitungan matematis menggunakan operator aritmatika, pengisian nilai melalui operator assignment, perbandingan nilai menggunakan operator perbandingan, pembentukan logika kompleks dengan operator logika, pemrosesan bit data menggunakan operator bitwise, hingga operator lainnya seperti operator identitas dan keanggotaan. Pemahaman mendalam mengenai fungsi serta prioritas kerja masing-masing operator sangat penting agar mahasiswa mampu membangun alur logika program yang akurat, efisien, dan presisi. Oleh karena itu, praktikum mengenai operator ini dilaksanakan sebagai langkah esensial dalam mengembangkan kemampuan pemrosesan logika pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Mengetahui dan memahami jenis-jenis operator dasar beserta fungsinya dalam bahasa pemrograman Python.
#
# 2. Mengimplementasikan operasi perhitungan matematis menggunakan operator aritmatika serta pengisian variabel dengan operator assignment.
#
# 3. Mengidentifikasi dan menerapkan operator perbandingan serta operator logika dalam pengambilan keputusan logika program.
#
# 4. Memahami pemrosesan data tingkat biner menggunakan operator bitwise serta penerapan operator pendukung lainnya seperti identitas (is) dan keanggotaan (in).
#
# ## 1.3 Manfaat
# 1. Menambah pengalaman mahasiswa dalam mengimplementasikan berbagai macam operasi logika dan aritmatika pada program Python.
# 2. Meningkatkan keterampilan dalam menggunakan VS Code sebagai lingkungan pengembangan kode program.
# 3. Memahami pemanfaatan GitHub untuk menyimpan, mengorganisir, dan mengelola repositori kode program secara terstruktur.
# 4. Mengasah kemampuan problem solving dan berpikir logis dalam memanipulasi data program.
# 5. Menjadi bekal dasar untuk membangun algoritma yang lebih kompleks dan tingkat lanjut pada praktikum berikutnya.

# %% [markdown]
# <h2 align="center">
# BAB II
#
# PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Pengolahan data dan pembuatan keputusan di dalam program membutuhkan sarana untuk memproses, memanipulasi, dan membandingkan nilai-nilai yang tersimpan di dalam memori. Operator berperan sebagai simbol atau kata kunci khusus yang menginstruksikan komputer untuk melakukan tindakan atau operasi tertentu terhadap satu atau beberapa nilai yang disebut sebagai operan.
# Python menyediakan berbagai kelompok operator standar yang digunakan dalam penyusunan logika program, antara lain:
# 1. Operator Aritmatika: Digunakan untuk melakukan operasi perhitungan matematis dasar, seperti penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), modulus/sisa bagi (%), dan perpangkatan (**).
# 2. Operator Assignment: Digunakan untuk memberikan atau memperbarui nilai pada suatu variabel. Selain operator pengisian dasar (=), Python juga mendukung compound assignment seperti +=, -=, *=, /=, %=, //=, dan **=.
# 3. Operator Perbandingan: Digunakan untuk membandingkan dua nilai dan menghasilkan keluaran berupa nilai logika boolean (True atau False). Operator ini meliputi sama dengan (==), tidak sama dengan (!=), lebih besar (>), lebih kecil (<), lebih besar sama dengan (>=), dan lebih kecil sama dengan (<=).
# 4. Operator Logika: Digunakan untuk mengombinasikan atau membalikkan kondisi logika boolean. Operator ini mencakup and (bernilai True jika kedua kondisi benar), or (bernilai True jika salah satu kondisi benar), dan not (membalikkan nilai kebenaran).
# 5. Operator Bitwise: Digunakan untuk melakukan operasi manipulasi data langsung pada tingkat biner (bit demi bit). Operator ini meliputi AND (&), OR (|), XOR (^), NOT (~), Left Shift (<<), dan Right Shift (>>).
# 6. Operator Lainnya (Identitas & Keanggotaan): Digunakan untuk memeriksa hubungan antar objek atau keberadaan suatu nilai. Operator identitas (is, is not) mengecek apakah dua variabel merujuk pada objek yang sama di memori, sedangkan operator keanggotaan (in, not in) mengecek keberadaan suatu nilai di dalam struktur data terurut.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611531010"

# %%
# Buat program untuk operator aritmatika dalam Pyhton

angka1_1010 = int(input("Input angka-1:"))
angka2_1010 = int(input("Input angka-2:"))

# Penjumalahan
hasil_1010 = angka1_1010 + angka2_1010
print("\nOperator Penjumalhan")
print("Hasil =", hasil_1010)

# Pengurangan
hasil_1010 = angka1_1010 - angka2_1010
print("\nOperator Pengurangan")
print("Hasil =", hasil_1010)

# Perkalian
hasil_1010 = angka1_1010 * angka2_1010
print("\nOperator Perkalian")
print("Hasil =", hasil_1010)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_1010 != 0:
    hasil_1010 = angka1_1010 / angka2_1010
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1010)

    hasil_1010 = angka1_1010 // angka2_1010
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1010)

    hasil_1010 = angka1_1010 % angka2_1010
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1010)
else:
    print("Angka kedua tidak boleh bernilai 0.")
    
# Pangkat
hasil_1010 = angka1_1010 ** angka2_1010
print("\nOperator Pangkat")
print("Hasil =", hasil_1010)

# %% [markdown]
# ```text
# Input angka-1:3
# Input angka-2:5
#
# Operator Penjumalhan
# Hasil = 8
#
# Operator Pengurangan
# Hasil = -2
#
# Operator Perkalian
# Hasil = 15
#
# Operator Pembagian
# Hasil = 0.6
#
# Operator Pembagian Bulat
# Hasil = 0
#
# Operator Sisa Bagi
# Hasil = 3
#
# Operator Pangkat
# Hasil = 243

# %% [markdown]
# **Penjelasan :**
#
# 1. **Penerimaan dan Konversi Input**
#
# * `input()` digunakan untuk mengambil masukan teks dari pengguna melalui terminal.
# * `int()` berfungsi melakukan *type casting* (pengubahan tipe data) dari teks (*string*) menjadi bilangan bulat (*integer*). Langkah ini wajib dilakukan agar variabel `angka1_1010` dan `angka2_1010` dapat dioperasikan secara matematis.
#
# 2. **Operasi Aritmatika Dasar**
#
# * **Penjumlahan (`+`)**: Menjumlahkan kedua nilai operan.
# * **Pengurangan (`-`)**: Mengurangi nilai pertama dengan nilai kedua.
# * **Perkalian (`*`)**: Mengalikan kedua nilai operan.
# Hasil dari setiap perhitungan disimpan sementara dalam variabel `hasil_1010` sebelum ditampilkan menggunakan fungsi `print()`.
#
# 3. **Penanganan Pembagian (`if-else`)**
# Dalam matematika dan pemrogaraman, pembagian dengan angka nol ($0$) akan menghasilkan *error* (*ZeroDivisionError*). Oleh karena itu, dibuat pemeriksaan kondisi:
#
# * `if angka2_1010 != 0:` mengecek apakah angka kedua tidak sama dengan nol.
# * **Pembagian (`/`)**: Menghasilkan nilai pembagian pecahan (*float*).
# * **Pembagian Bulat / Floor Division (`//`)**: Menghasilkan nilai bulat dari pembagian (pembulatan ke bawah).
# * **Sisa Bagi / Modulus (`%`)**: Menghasilkan sisa dari hasil pembagian dua bilangan.
#
#
# * `else:` berjalan jika pengguna memasukkan `angka2_1010` bernilai $0$, lalu menampilkan pesan peringatan tanpa mengeksekusi operasi pembagian.
#
# 4. **Operasi Perpangkatan**
#
# * **Pangkat (`**`)**: Menghitung hasil perpangkatan dengan format `basis ** eksponen` (nilai `angka1_1010` dipangkatkan sebanyak `angka2_1010`).

# %% [markdown]
# ### 2.2.2 Program "Assignment_2611531010"

# %%
# Program assignment dalam python

angka1_1010 = int(input("Input angka-1:"))
angka2_1010 = int(input("Input angka-2:"))

print("\nNilai awal angka1 =", angka1_1010)
print("Nilai awal angka2 =", angka2_1010)

# Assignement biasa
hasil_1010 = angka1_1010
print("\nAssignment Biasa (=)")
print("Hasil =", hasil_1010)

# Assignment penambahan
hasil_1010 = angka1_1010
hasil_1010 += angka2_1010   
print("\nAssignment Penambahan (+=)")
print("Hasil =", hasil_1010)

# Assignment pengurangan
hasil_1010 = angka1_1010
hasil_1010 -= angka2_1010
print("\nAssignment Pengurangan (-=)")
print("Hasil =", hasil_1010)

# Assignment perkalian
hasil_1010 = angka1_1010
hasil_1010 *= angka2_1010
print("\nAssignment Perkalian (*=)")
print("Hasil =", hasil_1010)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_1010 != 0:
    hasil_1010 = angka1_1010
    hasil_1010 /= angka2_1010
    print("\nAssignment Pembagian (/=)")
    print("Hasil =", hasil_1010)
    # Operator tambahan
    hasil_1010 = angka1_1010
    hasil_1010 //= angka2_1010  
    print("\nAssignment Pembagian Bulat (//=)")
    print("Hasil =", hasil_1010)
    hasil_1010 = angka1_1010
    hasil_1010 %= angka2_1010
    print("\nAssignment Sisa Bagi (%=)")
    print("Hasil =", hasil_1010)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedua tidak boleh bernilai 0.")
    
# Operator tambahan: assignment perpangkatan
hasil_1010 = angka1_1010
hasil_1010 **= angka2_1010
print("\nAssignment Perpangkatan (**=)")
print("Hasil =", hasil_1010)

# %% [markdown]
# ```text
# Nilai awal angka1 = 3
# Nilai awal angka2 = 4
#
# Assignment Biasa (=)
# Hasil = 3
#
# Assignment Penambahan (+=)
# Hasil = 7
#
# Assignment Pengurangan (-=)
# Hasil = -1
#
# Assignment Perkalian (*=)
# Hasil = 12
#
# Assignment Pembagian (/=)
# Hasil = 0.75
#
# Assignment Pembagian Bulat (//=)
# Hasil = 0
#
# Assignment Sisa Bagi (%=)
# Hasil = 3
#
# Assignment Perpangkatan (**=)
# Hasil = 81

# %% [markdown]
# **Penjelasan:**
#
# 1. **Input Data dari Pengguna**
#
# * Fungsi `input()` mengambil masukan dalam bentuk teks dari pengguna.
# * Fungsi `int()` mengubah (*type casting*) masukan tersebut menjadi tipe data bilangan bulat (*integer*) agar dapat diproses oleh operator aritmatika dan *assignment*.
#
# 2. **Pengisian Dasar (Standard Assignment `=`)**
#
# * `hasil_1010 = angka1_1010`: Mengisi nilai variabel `hasil_1010` dengan nilai yang tersimpan dalam `angka1_1010`.
#
# 3. **Operator Pengisian Gabungan (Compound Assignment)**
# Operator ini memadukan operasi aritmatika dengan pengisian nilai secara langsung ke dalam variabel penampung:
#
# * **Penambahan (`+=`)**: `hasil_1010 += angka2_1010` identik dengan `hasil_1010 = hasil_1010 + angka2_1010`. Menjumlahkan nilai `hasil_1010` dengan `angka2_1010`, lalu hasilnya disimpan kembali ke `hasil_1010`.
# * **Pengurangan (`-=`)**: `hasil_1010 -= angka2_1010` identik dengan `hasil_1010 = hasil_1010 - angka2_1010`. Mengurangi nilai `hasil_1010` dengan `angka2_1010`.
# * **Perkalian (`*=`)**: `hasil_1010 *= angka2_1010` identik dengan `hasil_1010 = hasil_1010 * angka2_1010`. Mengalikan nilai `hasil_1010` dengan `angka2_1010`.
#
# 4. **Penanganan Pembagian (`if-else`)**
# Pemeriksaan `if angka2_1010 != 0:` dilakukan untuk menghindari error *ZeroDivisionError* saat pembagi bernilai `0`. Jika tidak bernilai `0`, maka dilakukan operasi:
#
# * **Pembagian Real (`/=`)**: `hasil_1010 /= angka2_1010` (sama dengan `hasil_1010 = hasil_1010 / angka2_1010`), menghasilkan nilai desimal (*float*).
# * **Pembagian Bulat (`//=`)**: `hasil_1010 //= angka2_1010` (sama dengan `hasil_1010 = hasil_1010 // angka2_1010`), menghasilkan nilai bulat (*floor division*).
# * **Modulus/Sisa Bagi (`%=`)**: `hasil_1010 %= angka2_1010` (sama dengan `hasil_1010 = hasil_1010 % angka2_1010`), menyimpan sisa hasil pembagian.
#
# Jika pengguna memasukkan `angka2_1010` bernilai `0`, blok `else` akan berjalan dan menampilkan pesan bahwa pembagian tidak dapat dilakukan.
#
# 5. **Assignment Perpangkatan**
#
# * **Perpangkatan (`**=`)**: `hasil_1010 **= angka2_1010` identik dengan `hasil_1010 = hasil_1010 ** angka2_1010`. Memangkatkan nilai `hasil_1010` sebanyak `angka2_1010`.

# %% [markdown]
# ### 2.2.3 Program "Bitwise_2611531010"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n========================================")
print("3. OPERATOR BITWISE")
print("==========================================")

angka1_1010 = int(input("Masukkan angka bitwise-1: "))
angka2_1010 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_1010, "| biner =", bin(angka1_1010))
print("angka2 =", angka2_1010, "| biner =", bin(angka2_1010))

# Bitwise AND
hasil_1010 = angka1_1010 & angka2_1010
print("\nBitwise AND (&)")
print(angka1_1010, "&", angka2_1010, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# Bitwise OR
hasil_1010 = angka1_1010 | angka2_1010
print("\nBitwise OR (|)")
print(angka1_1010, "|", angka2_1010, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# Bitwise XOR
hasil_1010 = angka1_1010 ^ angka2_1010
print("\nBitwise XOR (^)")
print(angka1_1010, "^", angka2_1010, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# Bitwise NOT
hasil_1010 = ~angka1_1010
print("\nBitwise NOT (~)")
print("~", angka1_1010, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# Bitwise geser kiri
jumlah_geser = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_1010 = angka1_1010 << jumlah_geser
print("\nBitwise geser kiri (<<)")
print(angka1_1010, "<<", jumlah_geser, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# Bitwise geser kanan
hasil_1010 = angka1_1010 >> jumlah_geser
print("\nBitwise geser kanan (>>)")
print(angka1_1010, ">>", jumlah_geser, "=", hasil_1010)
print("Biner hasil =", bin(hasil_1010))
print("Biner hasil (8 bit) =", format(hasil_1010, "08b"))

# %% [markdown]
# ```text
# ========================================
# 3. OPERATOR BITWISE
# ==========================================
# Masukkan angka bitwise-1: 3
# Masukkan angka bitwise-2: 4
#
# Angka dalam bentuk desimal dan biner
# angka1 = 3 | biner = 0b11
# angka2 = 4 | biner = 0b100
#
# Bitwise AND (&)
# 3 & 4 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# 3 | 4 = 7
# Biner hasil = 0b111
# Biner hasil (8 bit) = 00000111
#
# Bitwise XOR (^)
# 3 ^ 4 = 7
# Biner hasil = 0b111
# Biner hasil (8 bit) = 00000111
#
# Bitwise NOT (~)
# ~ 3 = -4
# Biner hasil = -0b100
# Biner hasil (8 bit) = -0000100
#
# Masukkan jumlah pergeseran bit: 4
#
# Bitwise geser kiri (<<)
# 3 << 4 = 48
# Biner hasil = 0b110000
# Biner hasil (8 bit) = 00110000
#
# Bitwise geser kanan (>>)
# 3 >> 4 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000

# %% [markdown]
# **Penjelasan:**
#
# 1. **Input Data dan Tampilan Biner Dasar**
#
# * `input()` menerima masukan angka dalam bentuk teks, lalu `int()` mengonversinya menjadi bilangan bulat.
# * `bin()` digunakan untuk mengubah nilai desimal menjadi string biner dengan prefiks `0b`.
# * `format(nilai, "08b")` memformat nilai biner menjadi 8 bit lengkap dengan penambahan digit nol di depan jika panjang bit kurang dari 8.
#
# 2. **Bitwise AND (`&`)**
#
# * Membandingkan setiap bit dari dua angka.
# * Menghasilkan bit `1` hanya jika kedua bit yang dibandingkan bernilai `1`. Jika salah satu atau keduanya `0`, hasilnya adalah `0`.
#
# 3. **Bitwise OR (`|`)**
#
# * Membandingkan setiap bit dari dua angka.
# * Menghasilkan bit `1` jika salah satu atau kedua bit yang dibandingkan bernilai `1`. Hasilnya hanya akan `0` jika kedua bit bernilai `0`.
#
# 4. **Bitwise XOR (`^`)**
#
# * Membandingkan setiap bit dari dua angka (*Exclusive OR*).
# * Menghasilkan bit `1` jika bit yang dibandingkan nilainya berbeda (satu bernilai `1` dan satu bernilai `0`). Jika kedua bit bernilai sama (keduanya `1` atau keduanya `0`), hasilnya adalah `0`.
#
# 5. **Bitwise NOT (`~`)**
#
# * Membalikkan seluruh bit pada satu operan (mengubah bit `1` menjadi `0` dan bit `0` menjadi `1`).
# * Dalam sistem biner *Two's Complement* pada Python, rumus dasarnya adalah `~x = -(x + 1)`. Oleh karena itu, hasilnya berupa bilangan negatif.
#
# 6. **Bitwise Left Shift (`<<`)**
#
# * Menggeser seluruh bit angka ke arah kiri sebanyak digit yang ditentukan pada `jumlah_geser`.
# * Setiap pergeseran 1 bit ke kiri secara matematis setara dengan mengalikan nilai desimal dengan 2 ($x \times 2^n$).
#
# 7. **Bitwise Right Shift (`>>`)**
#
# * Menggeser seluruh bit angka ke arah kanan sebanyak digit yang ditentukan pada `jumlah_geser`.
# * Setiap pergeseran 1 bit ke kanan secara matematis setara dengan membagi nilai desimal dengan 2 secara bulat ($x // 2^n$).

# %% [markdown]
# ### 2.2.4 Program "Lainnya_2611531010"

# %%
# Program keanggotaan dan identitas dalam python

print("==================================")
print("1.OPERATOR KEANGGOTAAN")
print("==================================")

# Input beberapa data yang dipisahkan dengan koma'
Input_data = input("Input beberapa data, pisahkan dengan koma:")

# Mengubah input menjadi list integer
data = [int(angka.strip()) for angka in Input_data.split(",")]

nilai_dicari = int(input("Masukkan angka yang ingin dicari:"))

# Operator in
hasil_1010 = nilai_dicari in data
print("\nOperator keanggotaan IN")
print(nilai_dicari, "in data =", hasil_1010)

# Operator not in
hasil_1010 = nilai_dicari not in data
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari, "not in", data, "=", hasil_1010)
print("==================================")
print("2.OPERATOR IDENTITAS")
print("==================================")

# objek1 menggunakan list dari input pengguna
objek1_1010 = data

# objek2 merujuk pada objek yang sama dengan objek1
objek2_1010 = objek1_1010

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_1010 = data.copy()

print("objek1 =", objek1_1010)
print("objek2 =", objek2_1010)
print("objek3 =", objek3_1010)

# Operator is
hasil_1010 = objek1_1010 is objek2_1010
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_1010)

# Operator is not
hasil_1010 = objek1_1010 is not objek3_1010
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_1010)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_1010 is objek3_1010)
print("objek1 == objek3 =", objek1_1010 == objek3_1010)

# %% [markdown]
# ```text
# 1.OPERATOR KEANGGOTAAN
# ==================================
# Input beberapa data, pisahkan dengan koma:4,6
# Masukkan angka yang ingin dicari:9
#
# Operator keanggotaan IN
# 9 in data = False
#
# Operator keanggotaan NOT IN
# 9 not in [4, 6] = True
# ==================================
# 2.OPERATOR IDENTITAS
# ==================================
# objek1 = [4, 6]
# objek2 = [4, 6]
# objek3 = [4, 6]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan:**
#
# 1. **Pemrosesan Input dan Pembuatan List Data**
#
# * `input()` menerima rentetan angka yang dipisahkan oleh tanda koma dari pengguna.
# * `Input_data.split(",")` memotong teks input berdasarkan tanda koma menjadi elemen-elemen *string* terpisah.
# * *List comprehension* `[int(angka.strip()) for angka in ...]` memotong spasi liar (*strip*) pada setiap angka lalu mengonversinya (*type casting*) menjadi *integer* sehingga terbentuk sebuah *list* berisi angka.
#
# 2. **Operator Keanggotaan (*Membership Operators*)**
# Operator ini digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah struktur data terurut (seperti *list*).
#
# * **`in`**: Memeriksa keberadaan nilai. Mengembalikan `True` jika `nilai_dicari` ditemukan di dalam *list* `data`, dan `False` jika tidak ada.
# * **`not in`**: Memeriksa ketidakadaaan nilai. Mengembalikan `True` jika `nilai_dicari` **tidak** ada di dalam *list* `data`, dan `False` jika nilai tersebut ditemukan.
# 3. **Pembuatan dan Pengalokasian Objek di Memori**
#
# * **`objek1_1010 = data`**: Merujuk langsung pada *list* `data`.
# * **`objek2_1010 = objek1_1010`**: Mengacu ke referensi memori yang sama persis dengan `objek1_1010` (keduanya menunjuk ke satu alamat objek di memori).
# * **`objek3_1010 = data.copy()`**: Membuat salinan (*copy*) baru dari isi `data`. Walaupun nilainya identik, `objek3_1010` disimpan di lokasi/alamat memori yang berbeda.
#
# 4. **Operator Identitas (*Identity Operators*)**
# Operator identitas mengecek apakah dua variabel merujuk pada **objek atau lokasi memori yang sama**, bukan sekadar memiliki nilai yang sama.
#
# * **`is`**: Mengembalikan `True` jika kedua variabel menunjuk ke objek yang sama di memori. `objek1 is objek2` bernilai `True` karena keduanya berbagi alamat memori.
# * **`is not`**: Mengembalikan `True` jika kedua variabel menunjuk ke objek yang berbeda. `objek1 is not objek3` bernilai `True` karena `objek3` dibuat dari hasil `.copy()` sehingga menempati lokasi memori baru.
#
# 5. **Perbandingan Identitas (`is`) vs Perbandingan Nilai (`==`)**
#
# * **`objek1 is objek3` (`False`)**: Mengecek alamat memori. Bernilai `False` karena keduanya adalah dua objek yang berbeda di lokasi memori yang terpisah.
# * **`objek1 == objek3` (`True`)**: Mengecek nilai/konten. Bernilai `True` karena elemen-elemen di dalam kedua *list* tersebut persis sama.

# %% [markdown]
# ### 2.2.5 Program "Logika_2611531010"

# %%
# Program operator logika dalam python

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_1010 = input("Input nilai boolean-1 (True/False):").strip().lower() == "true"
a2_1010 = input("Input nilai boolean-2 (True/False):").strip().lower() == "true"

print("\nA1 =", a1_1010)
print("A2 =", a2_1010)

# Konjungsi: bernilai True jika keduanya True
hasil_1010 = a1_1010 and a2_1010
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_1010)

#Disjungsi: bernilai True jika salah satunya True
hasil_1010 = a1_1010 or a2_1010
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_1010)

# Negasi A1: membalik nilai A1
hasil_1010 = not a1_1010
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_1010)

# Negasi A2: membalik nilai A2
hasil_1010 = not a2_1010
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_1010)

# XOR: bernilai True jika kedua nilai berbeda
hasil_1010 = a1_1010 != a2_1010
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_1010)

# %% [markdown]
# ```text
# Input nilai boolean-1 (True/False):true
# Input nilai boolean-2 (True/False):true
#
# A1 = True
# A2 = True
#
# Konjungsi (AND)
# A1 and A2 = True
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = False
#
# Disjungsi Eksklusif (XOR)
# A1 XOR A2 = False

# %% [markdown]
# **Penjelasan:**
#
# 1. **Input dan Konversi Nilai Boolean**
#
# * `input()` menerima teks masukan dari pengguna melalui terminal.
# * `.strip()` menghapus spasi liar di awal atau akhir teks masukan.
# * `.lower()` mengubah seluruh huruf masukan menjadi huruf kecil (*case-insensitive*).
# * Ekspresi `== "true"` membandingkan teks masukan dengan string `"true"`. Jika pengguna memasukkan teks seperti `"True"`, `"TRUE"`, atau `"true"`, ekspresi ini menghasilkan nilai kebenaran logika `True`. Jika diisi selain itu, nilainya menjadi `False`.
#
# 2. **Konjungsi (`and`)**
# * Operator `and` mengevaluasi dua kondisi logika.
# * Menghasilkan nilai `True` **hanya jika** kedua variabel (`a1_1010` dan `a2_1010`) bernilai `True`. Jika salah satu atau keduanya bernilai `False`, hasilnya adalah `False`.
#
# 3. **Disjungsi (`or`)**
#
# * Operator `or` mengevaluasi dua kondisi logika.
# * Menghasilkan nilai `True` jika **salah satu atau kedua** variabel bernilai `True`. Hasilnya hanya akan `False` jika kedua variabel bernilai `False`.
#
# 4. **Negasi (`not`)**
#
# * Operator `not` membalikkan nilai logika dari satu operan.
# * Mengubah nilai `True` menjadi `False`, dan sebaliknya mengubah `False` menjadi `True`. Di program ini, negasi dievaluasi secara terpisah untuk `a1_1010` dan `a2_1010`.
#
# 5. **Disjungsi Eksklusif / XOR (`!=`)**
#
# * Python tidak memiliki operator kata kunci khusus `xor` untuk nilai boolean standar, sehingga digunakan operator tidak sama dengan (`!=`).
# * Menghasilkan nilai `True` jika kedua variabel memiliki nilai logika yang **berbeda** (satu `True` dan satu `False`). Jika kedua variabel nilainya sama (keduanya `True` atau keduanya `False`), hasilnya adalah `False`.

# %% [markdown]
# ### 2.2.5 Program "Perbandingan_2611531010"

# %%
# Program operator perbandingan dalam python

angka1 = int(input("Input angka-1:"))
angka2 = int(input("Input angka-2:"))

# Lebih besar dari
hasil = angka1 > angka2
print("\nOperator Lebih Besar Dari")
print("angka1 > angka2 =", hasil)

# Lebih kecil dari
hasil = angka1 < angka2
print("\nOperator Lebih Kecil Dari")
print("angka1 < angka2 =", hasil)


# Lebih besar dari atau sama dengan
hasil = angka1 >= angka2
print("\nOperator Lebih Besar Dari atau Sama Dengan")
print("angka1 >= angka2 =", hasil)

# Lebih kecil dari atau sama dengan
hasil = angka1 <= angka2
print("\nOperator Lebih Kecil Dari atau Sama Dengan")
print("angka1 <= angka2 =", hasil)

# Sama dengan
hasil = angka1 == angka2
print("\nOperator Sama Dengan")
print("angka1 == angka2 =", hasil)

# Tidak sama dengan
hasil = angka1 != angka2
print("\nOperator Tidak Sama Dengan")
print("angka1 != angka2 =", hasil)

# Tambahan: perbandingan berantai dalam python
hasil = 0 < angka1 < 100
print("\nOperator Perbandingan Berantai")
print("0 < angka1 < 100 =", hasil)

hasil = 0 < angka2 < 100
print("0 < angka2 < 100 =", hasil)

# %% [markdown]
# ```text
# Input angka-1:5
# Input angka-2:7
#
# Operator Lebih Besar Dari
# angka1 > angka2 = False
#
# Operator Lebih Kecil Dari
# angka1 < angka2 = True
#
# Operator Lebih Besar Dari atau Sama Dengan
# angka1 >= angka2 = False
#
# Operator Lebih Kecil Dari atau Sama Dengan
# angka1 <= angka2 = True
#
# Operator Sama Dengan
# angka1 == angka2 = False
#
# Operator Tidak Sama Dengan
# angka1 != angka2 = True
#
# Operator Perbandingan Berantai
# 0 < angka1 < 100 = True
# 0 < angka2 < 100 = True

# %% [markdown]
# **Penjelasan:**
#
# 1. **Input Data dari Pengguna**
#
# * `input()` menerima masukan teks dari pengguna melalui terminal.
# * `int()` mengubah (*type casting*) masukan teks tersebut menjadi bilangan bulat (*integer*) agar nilai pada variabel `angka1` dan `angka2` dapat dibanding secara numerik.
#
# 2. **Operator Perbandingan Dasar**
# Operator perbandingan membandingkan dua nilai dan selalu mengembalikan hasil berupa nilai logika boolean (`True` atau `False`):
#
# * **Lebih Besar Dari (`>`)**: Menghasilkan `True` jika `angka1` nilainya lebih besar dari `angka2`.
# * **Lebih Kecil Dari (`<`)**: Menghasilkan `True` jika `angka1` nilainya lebih kecil dari `angka2`.
# * **Lebih Besar Sama Dengan (`>=`)**: Menghasilkan `True` jika `angka1` lebih besar atau nilainya sama persis dengan `angka2`.
# * **Lebih Kecil Sama Dengan (`<=`)**: Menghasilkan `True` jika `angka1` lebih kecil atau nilainya sama persis dengan `angka2`.
# * **Sama Dengan (`==`)**: Menghasilkan `True` jika nilai `angka1` sama persis dengan `angka2`.
# * **Tidak Sama Dengan (`!=`)**: Menghasilkan `True` jika nilai `angka1` berbeda atau tidak sama dengan `angka2`.
#
# 3. **Perbandingan Berantai (*Chained Comparison*)**
# Python mendukung fitur penulisan perbandingan berantai secara langsung tanpa perlu menggabungkan dua kondisi secara terpisah:
#
# * `0 < angka1 < 100` identik secara logika dengan `0 < angka1 and angka1 < 100`.
# * Ekspresi ini memeriksa apakah nilai variabel berada di dalam rentang (*range*) antara 1 hingga 99 (lebih besar dari 0 **dan** lebih kecil dari 100). Jika memenuhi kedua syarat tersebut, hasilnya adalah `True`.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal prak3.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2611531010"

# %%
# ==============================================================================
# STUDI KASUS: SISTEM SIMULASI TRANSAKSI DAN VALIDASI AKSES TOKO
# Nama File : tugas3_1010.py
# ==============================================================================

print("=== SISTEM TRANSAKSI TOKO ===")

# ------------------------------------------------------------------------------
# 1. INPUT DATA PELANGGAN DAN TRANSAKSI
# ------------------------------------------------------------------------------
nama_1010 = input("Masukkan Nama Pelanggan : ")
status_pelanggan_1010 = input("Masukkan Status Pelanggan (member/nonmember) : ").strip().lower()
total_belanja_1010 = float(input("Masukkan Total Belanja : "))
jumlah_barang_1010 = int(input("Masukkan Jumlah Barang : "))
kode_promo_1010 = input("Masukkan Kode Promo : ").strip().upper()

# Daftar promo yang valid
daftar_promo_1010 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

# ------------------------------------------------------------------------------
# 2. OPERATOR PERBANDINGAN & LOGIKA (VALIDASI)
# ------------------------------------------------------------------------------
# Operator Perbandingan
min_belanja_1010 = total_belanja_1010 >= 200000
min_barang_1010 = jumlah_barang_1010 >= 3
is_member_1010 = status_pelanggan_1010 == "member"

# Operator Keanggotaan (Membership)
promo_valid_1010 = kode_promo_1010 in daftar_promo_1010
promo_invalid_1010 = kode_promo_1010 not in daftar_promo_1010

# Operator Logika (and, or, not)
dapat_diskon_1010 = is_member_1010 and min_belanja_1010
dapat_promo_1010 = promo_valid_1010 or (min_barang_1010 and min_belanja_1010)
bukan_member_1010 = not is_member_1010

# ------------------------------------------------------------------------------
# 3. OPERATOR ARITMATIKA & PENUGASAN (CALCULATION)
# ------------------------------------------------------------------------------
# Operator Aritmatika dasar
persen_diskon_1010 = 0.10 if dapat_diskon_1010 else 0.0
besarnya_diskon_1010 = total_belanja_1010 * persen_diskon_1010
total_pembayaran_1010 = total_belanja_1010 - besarnya_diskon_1010

# Operator Aritmatika / (Pembagian) & % (Modulus)
rata_rata_harga_1010 = total_belanja_1010 / jumlah_barang_1010 if jumlah_barang_1010 > 0 else 0
sisa_barang_1010 = jumlah_barang_1010 % 3  # Sisa pembagian per paket isi 3

# Operator Penugasan (Augmented Assignment)
poin_1010 = 0
poin_1010 += int(total_pembayaran_1010 // 10000)  # Tambah 1 poin tiap Rp10.000

if dapat_promo_1010 and kode_promo_1010 == "HEMAT10":
    total_pembayaran_1010 -= 10000  # Potongan tambahan Rp10.000

# ------------------------------------------------------------------------------
# 4. OPERATOR IDENTITAS (IDENTITY)
# ------------------------------------------------------------------------------
# Menunjukkan perbedaan antara 'is' (identitas objek) dan '==' (kesamaan nilai)
list_promo_A_1010 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
list_promo_B_1010 = list_promo_A_1010
list_promo_C_1010 = list_promo_A_1010.copy()

is_objek_sama_1010 = list_promo_A_1010 is list_promo_B_1010       # True
is_objek_beda_1010 = list_promo_A_1010 is not list_promo_C_1010   # True
is_nilai_sama_1010 = list_promo_A_1010 == list_promo_C_1010       # True

# ------------------------------------------------------------------------------
# 5. OPERATOR BITWISE (HAK AKSES & KODE STATUS)
# ------------------------------------------------------------------------------
# Definisi Bit Flag
BIT_MEMBER_1010 = 0b0001  # 1
BIT_BELANJA_1010 = 0b0010  # 2
BIT_BARANG_1010  = 0b0100  # 4
BIT_PROMO_1010   = 0b1000  # 8

# Pembentukan Kode Status Transaksi Menggunakan Operator Bitwise OR (|)
kode_status_1010 = 0b0000
if is_member_1010:
    kode_status_1010 |= BIT_MEMBER_1010
if min_belanja_1010:
    kode_status_1010 |= BIT_BELANJA_1010
if min_barang_1010:
    kode_status_1010 |= BIT_BARANG_1010
if promo_valid_1010:
    kode_status_1010 |= BIT_PROMO_1010

# Pemeriksaan Akses Menggunakan Operator Bitwise AND (&)
cek_member_1010 = (kode_status_1010 & BIT_MEMBER_1010) != 0
cek_promo_1010  = (kode_status_1010 & BIT_PROMO_1010) != 0

# Perbandingan Status Menggunakan Operator Bitwise XOR (^)
kode_referensi_1010 = 0b1011  # Referensi standar (Member + Belanja + Promo)
perbedaan_status_1010 = kode_status_1010 ^ kode_referensi_1010

# Bitwise Shift (<<)
shifted_status_1010 = kode_status_1010 << 1

# ------------------------------------------------------------------------------
# 6. OUTPUT HASIL TRANSAKSI DAN OPERATOR
# ------------------------------------------------------------------------------
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan        : {nama_1010}")
print(f"Status Pelanggan      : {status_pelanggan_1010}")
print(f"Total Belanja         : Rp{int(total_belanja_1010)}")
print(f"Jumlah Barang         : {jumlah_barang_1010}")
print(f"Kode Promo            : {kode_promo_1010}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000   : {min_belanja_1010}")
print(f"Jumlah Barang >= 3    : {min_barang_1010}")
print(f"Status Member         : {is_member_1010}")
print(f"Kode Promo Tersedia   : {promo_valid_1010}")
print(f"Mendapatkan Diskon    : {dapat_diskon_1010}")
print(f"Mendapatkan Promo     : {dapat_promo_1010}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                : Rp{int(besarnya_diskon_1010)}")
print(f"Total Pembayaran      : Rp{int(total_pembayaran_1010)}")
print(f"Rata-rata Harga Barang: Rp{int(rata_rata_harga_1010)}")
print(f"Poin Diperoleh        : {poin_1010}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Status Transaksi : {format(kode_status_1010, '04b')}")
print(f"Member Access         : {cek_member_1010}")
print(f"Promo Access          : {cek_promo_1010}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print("0001 | 0010 | 0100 | 1000")
print(f"Kode Biner   : {format(kode_status_1010, '04b')}")
print(f"Kode Desimal : {kode_status_1010}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(kode_status_1010, '04b')} & 0001")
print(f"Hasil Biner   : {format(kode_status_1010 & BIT_MEMBER_1010, '04b')}")
print(f"Hasil Desimal : {kode_status_1010 & BIT_MEMBER_1010}")

print("\nCek Promo")
print(f"{format(kode_status_1010, '04b')} & 1000")
print(f"Hasil Biner   : {format(kode_status_1010 & BIT_PROMO_1010, '04b')}")
print(f"Hasil Desimal : {kode_status_1010 & BIT_PROMO_1010}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(kode_status_1010, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_1010, '04b')}")
print(f"{format(kode_status_1010, '04b')} ^ {format(kode_referensi_1010, '04b')}")
print(f"Hasil Biner   : {format(perbedaan_status_1010, '04b')}")
print(f"Hasil Desimal : {perbedaan_status_1010}")

print("\n=== Shift ===")
print(f"{format(kode_status_1010, '04b')} << 1")
print(f"Hasil Biner   : {format(shifted_status_1010, '05b')}")
print(f"Hasil Desimal : {shifted_status_1010}")

print("\n=== OPERATOR IDENTITAS ===")
print(f"list_promo_A is list_promo_B : {is_objek_sama_1010}")
print(f"list_promo_A is not list_promo_C : {is_objek_beda_1010}")
print(f"list_promo_A == list_promo_C : {is_nilai_sama_1010}")

print("\n=== SELESAI ===")

# %% [markdown]
# ```text
# === SISTEM TRANSAKSI TOKO ===
# Masukkan Nama Pelanggan : humaira
# Masukkan Status Pelanggan (member/nonmember) : member
# Masukkan Total Belanja : 78000
# Masukkan Jumlah Barang : 17
# Masukkan Kode Promo :  5678
#
# === DATA TRANSAKSI ===
# Nama Pelanggan        : humaira
# Status Pelanggan      : member
# Total Belanja         : Rp78000
# Jumlah Barang         : 17
# Kode Promo            : 5678
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000   : False
# Jumlah Barang >= 3    : True
# Status Member         : True
# Kode Promo Tersedia   : False
# Mendapatkan Diskon    : False
# Mendapatkan Promo     : False
#
# === HASIL PERHITUNGAN ===
# Diskon                : Rp0
# Total Pembayaran      : Rp78000
# Rata-rata Harga Barang: Rp4588
# Poin Diperoleh        : 7
#
# === HAK AKSES PELANGGAN ===
# Kode Status Transaksi : 0101
# Member Access         : True
# Promo Access          : False
#
# === OPERASI BITWISE ===
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# Kode Biner   : 0101
# Kode Desimal : 5
#
# === Pemeriksaan Status ===
# Cek Member
# 0101 & 0001
# Hasil Biner   : 0001
# Hasil Desimal : 1
#
# Cek Promo
# 0101 & 1000
# Hasil Biner   : 0000
# Hasil Desimal : 0
#
# === Perbandingan Status ===
# Kode Transaksi : 0101
# Kode Referensi : 1011
# 0101 ^ 1011
# Hasil Biner   : 1110
# Hasil Desimal : 14
#
# === Shift ===
# 0101 << 1
# Hasil Biner   : 01010
# Hasil Desimal : 10
#
# === OPERATOR IDENTITAS ===
# list_promo_A is list_promo_B : True
# list_promo_A is not list_promo_C : True
# list_promo_A == list_promo_C : True
#
# === SELESAI ===

# %% [markdown]
# **Penjelasan:**
#
# 1. **Header & Input Data Pelanggan**
#
# * `print("=== SISTEM TRANSAKSI TOKO ===")`: Menampilkan judul utama program ke terminal.
# * `nama_1010 = input(...)`: Menerima masukan nama pelanggan berupa *string*.
# * `status_pelanggan_1010 = input(...).strip().lower()`: Menerima input status (`member`/`nonmember`), menghapus spasi liar dengan `.strip()`, dan mengubah huruf menjadi kecil dengan `.lower()`.
# * `total_belanja_1010 = float(input(...))`: Menerima input angka total belanja lalu mengonversinya menjadi tipe desimal (`float`).
# * `jumlah_barang_1010 = int(input(...))`: Menerima input jumlah barang lalu mengonversinya menjadi tipe bilangan bulat (`int`).
# * `kode_promo_1010 = input(...).strip().upper()`: Menerima kode promo, menghapus spasi, dan mengubahnya menjadi huruf kapital (`.upper()`).
# * `daftar_promo_1010 = [...]`: Deklarasi *list* penampung daftar kode promo resmi yang berlaku di toko.
#
#
# 2. **Operator Perbandingan & Logika (Validasi)**
#
# * `min_belanja_1010 = total_belanja_1010 >= 200000`: Menguji apakah belanja bernilai $200.000$ atau lebih (`True`/`False`).
# * `min_barang_1010 = jumlah_barang_1010 >= 3`: Menguji apakah jumlah barang bernilai $3$ atau lebih.
# * `is_member_1010 = status_pelanggan_1010 == "member"`: Menguji apakah status bernilai teks `"member"`.
# * `promo_valid_1010 = kode_promo_1010 in daftar_promo_1010`: Operator keanggotaan `in` mengecek keberadaan kode promo di dalam *list*.
# * `promo_invalid_1010 = kode_promo_1010 not in daftar_promo_1010`: Operator `not in` mengecek ketidakberadaan kode promo di dalam *list*.
# * `dapat_diskon_1010 = is_member_1010 and min_belanja_1010`: Operator `and` memastikan diskon member hanya didapat jika pelanggan adalah *member* **dan** belanja $\ge 200.000$.
# * `dapat_promo_1010 = promo_valid_1010 or (min_barang_1010 and min_belanja_1010)`: Operator `or` memberikan promo jika kode promo terdaftar **atau** jika belanjaan memenuhi syarat barang dan total nominal.
# * `bukan_member_1010 = not is_member_1010`: Operator `not` membalik nilai logika `is_member_1010`.
#
#
# 3. **Operator Aritmatika & Penugasan (Kalkulasi)**
#
# * `persen_diskon_1010 = 0.10 if dapat_diskon_1010 else 0.0`: Mengatur persentase diskon sebesar $10\%$ ($0.10$) jika `dapat_diskon_1010` bernilai `True`.
# * `besarnya_diskon_1010 = total_belanja_1010 * persen_diskon_1010`: Operator perkalian (`*`) menghitung potongan harga.
# * `total_pembayaran_1010 = total_belanja_1010 - besarnya_diskon_1010`: Operator pengurangan (`-`) menghitung total bayar setelah diskon.
# * `rata_rata_harga_1010 = total_belanja_1010 / jumlah_barang_1010 ...`: Operator pembagian (`/`) menghitung harga rata-rata tiap item.
# * `sisa_barang_1010 = jumlah_barang_1010 % 3`: Operator modulus (`%`) mencari sisa pembagian barang.
# * `poin_1010 = 0`: Inisialisasi variabel poin awal.
# * `poin_1010 += int(total_pembayaran_1010 // 10000)`: Operator *floor division* (`//`) membagi kelipatan $10.000$, lalu *augmented assignment* (`+=`) menambahkan hasilnya ke `poin_1010`.
# * `if dapat_promo_1010 and kode_promo_1010 == "HEMAT10":`: Menguji kondisi promo ekstra.
# * `total_pembayaran_1010 -= 10000`: Operator *augmented assignment* (`-=`) mengurangi total bayar sebesar $10.000$.
#
#
# 4. **Operator Identitas (Identity)**
#
# * `list_promo_A_1010 = [...]`: Membuat *list* promo A di memori.
# * `list_promo_B_1010 = list_promo_A_1010`: Membuat referensi B yang menunjuk ke alamat memori yang sama dengan A.
# * `list_promo_C_1010 = list_promo_A_1010.copy()`: Membuat objek *list* C baru hasil salinan isi A (alamat memori berbeda).
# * `is_objek_sama_1010 = list_promo_A_1010 is list_promo_B_1010`: Operator `is` menghasilkan `True` karena A dan B berbagi alamat memori.
# * `is_objek_beda_1010 = list_promo_A_1010 is not list_promo_C_1010`: Operator `is not` menghasilkan `True` karena A dan C beda lokasi memori.
# * `is_nilai_sama_1010 = list_promo_A_1010 == list_promo_C_1010`: Operator `==` menghasilkan `True` karena konten/isi A dan C sama.
#
#
# 5. **Operator Bitwise (Hak Akses & Status)**
#
# * `BIT_MEMBER_1010 = 0b0001` hingga `BIT_PROMO_1010 = 0b1000`: Deklarasi nilai bit flag untuk tiap syarat kondisi.
# * `kode_status_1010 = 0b0000`: Inisialisasi kode status transaksi biner $0$.
# * `if ...: kode_status_1010 |= BIT_...`: Operator Bitwise OR (`|=`) mengombinasikan/menyalakan bit kondisi yang bernilai `True`.
# * `cek_member_1010 = (kode_status_1010 & BIT_MEMBER_1010) != 0`: Operator Bitwise AND (`&`) memeriksa apakah bit member aktif.
# * `cek_promo_1010 = (kode_status_1010 & BIT_PROMO_1010) != 0`: Operator Bitwise AND (`&`) memeriksa bit promo.
# * `kode_referensi_1010 = 0b1011`: Inisialisasi kode biner pembanding/standar.
# * `perbedaan_status_1010 = kode_status_1010 ^ kode_referensi_1010`: Operator Bitwise XOR (`^`) mengecek perbedaan bit antara transaksi dan standar.
# * `shifted_status_1010 = kode_status_1010 << 1`: Operator Bitwise *Left Shift* (`<<`) menggeser posisi bit ke kiri sebanyak 1 digit.
#
#
# 6. **Output Hasil Transaksi dan Operator**
#
# * `print(f"...")`: Seluruh baris `print` di bagian akhir menggunakan *formatted string* (`f"..."`) untuk menampilkan nilai variabel, angka yang dibulatkan (`int()`), format biner (`04b`), serta perincian langkah-langkah kalkulasi biner ke layar terminal.

# %% [markdown]
# ### Pertanyaan Analisis pada Laporan
#
# 1.   Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
#
# * Perkalian (`*`): Digunakan untuk menghitung besarnya nilai diskon (`total_belanja_1010 * persen_diskon_1010`).
# * Pengurangan (`-`): Digunakan untuk menghitung total akhir pembayaran (`total_belanja_1010 - besarnya_diskon_1010`).
# * Pembagian (`/`): Digunakan untuk mendapatkan harga rata-rata tiap item (`total_belanja_1010 / jumlah_barang_1010`).
# * Floor Division (`//`): Digunakan untuk menghitung perolehan poin per kelipatan Rp10.000.
# * Modulus (`%`): Digunakan untuk menghitung sisa barang luar paket promo (`jumlah_barang_1010 % 3`).
#
# 2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
#
# * `and`: Mengembalikan `True` hanya jika **semua** kondisi bernilai `True`. Contoh: `dapat_diskon_1010 = is_member_1010 and min_belanja_1010` (harus member **dan** belanja $\ge$ Rp200.000).
# * `or`: Mengembalikan `True` jika **salah satu** kondisi bernilai `True`. Contoh: `dapat_promo_1010 = promo_valid_1010 or (...)` (cukup salah satu dari promo valid atau syarat barang terpenuhi).
# * `not`: Membalikkan nilai kebenaran. Contoh: `not is_member_1010` akan bernilai `True` jika pelanggan adalah non-member (`False`).
#
# 3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
#
# * `in`: Memeriksa apakah kata kunci `kode_promo_1010` yang dimasukkan pengguna ada di dalam daftar `["HEMAT10", "HEMAT20", "GRATISONGKIR"]`.
# * `not in`: Memeriksa apakah kode promo yang diinput **tidak terdaftar** dalam sistem toko.
#
# 4. Apa perbedaan antara is dan == pada Python?
#
# * `is`: Menguji **identitas objek** (apakah kedua variabel merujuk pada alamat memori/lokasi fisik yang sama persis).
# * `==`: Menguji **kesamaan nilai/isi** (apakah konten dari dua objek bernilai sama, meskipun berada di alamat memori yang berbeda).
# * *Contoh pada program*: `list_promo_A is list_promo_C` bernilai `False` karena `list_promo_C` dibuat dengan `.copy()` (alamat memori beda), tetapi `list_promo_A == list_promo_C` bernilai `True` karena isi elemen keduanya identik.
#
# 5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
# Setiap syarat direpresentasikan oleh 1 bit biner:
#
# * Bit 0 (`0001`): Status Member
# * Bit 1 (`0010`): Belanja $\ge$ Rp200.000
# * Bit 2 (`0100`): Barang $\ge$ 3
# * Bit 3 (`1000`): Kode Promo Valid
#
# Operator `|` (OR) digunakan untuk menggabungkan bit kondisi pelanggan menjadi sebuah *kode status* (misal: `1111`). Operator `&` (AND) digunakan sebagai *masking* untuk menguji apakah bit tertentu aktif (misal `1111 & 0001` menghasilkan `0001` yang berarti akses member aktif). Operator `^` (XOR) membandingkan perbedaan bit antara status pelanggan dengan profil referensi standar.
#
# 6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
#
# -  **Input**: Menerima input dari pengguna (nama, status, belanja, jumlah barang, kode promo).
# - **Validasi**: Mengevaluasi kondisi dasar menggunakan operator perbandingan (`>=`, `==`) dan keanggotaan (`in`).
# -  **Logika**: Menggabungkan hasil validasi menggunakan operator logika (`and`, `or`) untuk menentukan kelayakan diskon dan promo.
# -  **Perhitungan**: Menghitung besarnya diskon, total bayar, rata-rata harga, serta memperbarui nilai pembayaran dengan operator penugasan (`-=`, `+=`).
# -  **Bitwise & Identitas**: Menggabungkan bit status dengan Bitwise OR, menguji akses dengan Bitwise AND, serta memverifikasi referensi memori dengan `is`.
# -  **Output**: Menampilkan ringkasan data transaksi, hasil perhitungan, validasi, dan rincian biner ke layar.
#
# 7.  Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# * **Kondisi yang menghasilkan `True**`: `min_belanja_1010` bernilai `True` saat pengguna memasukkan total belanja `250000` ($\ge 200000$).
# * **Kondisi yang menghasilkan `False**`: `promo_valid_1010` bernilai `False` jika pengguna memasukkan kode promo `HEMAT50` (karena tidak ada dalam daftar `daftar_promo_1010`).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum mengenai operator dalam bahasa pemrograman Python yang telah dilaksanakan, dapat disimpulkan bahwa:
# 1. Pemahaman Jenis dan Fungsi Operator: Operator dalam Python berfungsi sebagai sarana utama untuk memanipulasi, mengevaluasi, dan memproses data, mulai dari pengolahan angka secara sistematis hingga penentuan keputusan alur program.
# 2. Pengolahan Matematis dan Penugasan: Operator aritmatika (+, -, *, /, //, %, **) dan operator assignment (=, +=, -=, *=, /=, //=, %=, **=) mempermudah perhitungan transaksi serta pembaruan nilai variabel penampung secara efisien.
# 3. Pengambilan Keputusan Logika: Operator perbandingan (==, !=, >, <, >=, <=) dan operator logika (and, or, not) memungkinkan program untuk mengevaluasi multi-kondisi, seperti syarat batas minimum belanja, status keanggotaan, dan keabsahan promo.
# 4. Keanggotaan dan Identitas Memori: Operator keanggotaan (in, not in) terbukti efektif untuk melakukan pencarian nilai dalam struktur data terurut, sedangkan operator identitas (is, is not) membantu membedakan kesamaan referensi alamat memori objek dengan kesamaan isi nilai (==).
# 5. Manipulasi Biner dan Hak Akses: Operator bitwise (&, |, ^, ~, <<, >>) dapat dimanfaatkan untuk membentuk bit flag atau kode status biner yang efisien dalam memeriksa dan mengelola hak akses pelanggan pada sistem transaksi.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] GitHub, Inc. (2026). GitHub Docs: About Repositories and Git Version Control. Diakses dari https://docs.github.com/
#
# [2] Python Software Foundation. (2026). Python 3 Documentation: Expressions and Operators. Diakses dari https://docs.python.org/3/reference/expressions.html
#
# [3] Sweigart, A. (2019). Automate the Boring Stuff with Python (2nd ed.). San Francisco: No Starch Press.
#
# [4] W3Schools. (2026). Python Operators Tutorial. Diakses dari https://www.w3schools.com/python/python_operators.asp
