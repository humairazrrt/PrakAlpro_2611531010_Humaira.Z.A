# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Humaira Zahratul 'Aini**
#
# **2611531010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h2 align="center">KATA PENGANTAR</h2>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan ...
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep ... pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <div align="right">
#
# Padang, 2026
#
# <br><br><br>
#
# **Humaira Zahratul 'Aini**
# 2611531010
#
# </div>

# %% [markdown]
# <h2 align="center">
# BAB I
#
# PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman menjadi salah satu dasar yang penting untuk dipelajari dalam bidang Informatika. Bagi mahasiswa Informatika semester 1, pemahaman mengenai dasar-dasar pemrograman sangat diperlukan sebagai bekal untuk mempelajari materi yang lebih lanjut. Salah satu bahasa pemrograman yang sesuai untuk dipelajari oleh pemula adalah Python karena memiliki struktur dan sintaks yang relatif sederhana.
#
# Untuk membuat dan menjalankan program, dibutuhkan perangkat lunak pendukung seperti Visual Studio Code (VS Code). Selain itu, GitHub dapat dimanfaatkan sebagai tempat untuk menyimpan serta mengelola kode program secara daring. Berdasarkan hal tersebut, praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub dilaksanakan untuk mengenalkan penggunaan ketiga teknologi tersebut dalam proses pembuatan dan pengelolaan program sederhana.
#
# ## 1.2 Tujuan
# 1. Mengetahui dasar-dasar pemrograman menggunakan Python.
# 2. Mampu membuat dan menjalankan program Python melalui Visual Studio Code.
# 3. Mengetahui cara menghubungkan proyek dari VS Code dengan GitHub.
# 4. Memahami fungsi GitHub dalam penyimpanan dan pengelolaan kode.
# 5. Menerapkan penggunaan Python, VS Code, dan GitHub melalui proyek sederhana.
#
# ## 1.3 Manfaat
# 1. Menambah pengalaman mahasiswa dalam membuat serta menjalankan program Python.
# 2. Meningkatkan keterampilan dalam menggunakan VS Code sebagai editor kode.
# 3. Memahami pemanfaatan GitHub untuk menyimpan dan mengatur kode program.
# 4. Membantu mahasiswa mengelola proyek pemrograman dengan lebih terorganisir.
# 5. Menjadi bekal awal untuk mempelajari dan mengembangkan proyek pemrograman berikutnya.

# %% [markdown]
# <h2 align="center">
# BAB II
#
# PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Praktikum ini membahas pengenalan bahasa pemrograman Python, penggunaan Visual Studio Code sebagai alat untuk membuat program, serta pemanfaatan GitHub dalam menyimpan dan mengelola kode.
#
# 1. Python
# Python adalah bahasa pemrograman tingkat tinggi dengan sintaks yang sederhana dan mudah dipelajari. Python dapat digunakan dalam berbagai bidang, seperti pembuatan aplikasi, pengolahan data, dan pengembangan perangkat lunak.
# 2. Visual Studio Code
# Visual Studio Code (VS Code) merupakan aplikasi editor kode yang digunakan untuk menulis, mengedit, dan menjalankan program. VS Code mendukung banyak bahasa pemrograman, termasuk Python, serta memiliki fitur seperti terminal, debugging, dan integrasi Git.
# 3. Git
# Git adalah sistem pengontrol versi yang berfungsi untuk mencatat dan mengelola perubahan dalam suatu proyek. Penggunaan Git memudahkan programmer dalam mengatur berbagai versi kode program.
# 4. GitHub
# GitHub adalah platform daring yang digunakan untuk menyimpan repository berbasis Git. GitHub memungkinkan kode program dicadangkan secara online, diakses dari berbagai perangkat, serta digunakan untuk berkolaborasi dengan pengguna lain.
# 5. Repository
# Repository adalah tempat yang digunakan untuk menyimpan sebuah proyek beserta kode dan file pendukungnya. Repository dapat berada di komputer secara lokal maupun tersimpan secara online di GitHub.
# 6. Commit dan Push
# Commit merupakan proses mencatat perubahan yang telah dibuat pada repository lokal. Sementara itu, push digunakan untuk mengirim perubahan tersebut dari repository lokal ke repository yang tersimpan di GitHub.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "AlproC_2611531010"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
#Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini dibuat oleh Humaira Zahratul Aini_2611531010")

# %% [markdown]
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh Humaira Zahratul Aini 2611531010

# %% [markdown]
# **Penjelasan :**
# 1. print() digunakan untuk menampilkan teks pada layar.
# 2. print() tanpa isi digunakan untuk membuat baris kosong.
# 3. Tanda \ digunakan sebagai karakter khusus agar dapat menampilkan simbol tertentu.
# 4. print() terakhir menampilkan nama dan NIM pembuat program.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal prak1.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas1_2611531010"

# %%
# tugas1_2611531010.py

print("       **       **       ")
print("     ******   ******     ")
print("   ********* *********   ")
print("  *********************  ")
print(" ************************ ")
print(" ************************ ")
print("  *********************  ")
print("   *******************   ")
print("    *****************    ")
print("      *************      ")
print("        *********        ")
print("          *****          ")
print("           ***           ")
print("            *            ")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="image/output tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tersebut digunakan untuk menampilkan pola berbentuk hati (love) pada layar menggunakan karakter *. Setiap print() mencetak satu baris pola dengan jumlah dan posisi * yang berbeda sehingga membentuk gambar hati yang simetris. Program ini tidak menggunakan input, variabel, maupun perulangan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang memiliki sintaks sederhana sehingga sesuai digunakan untuk mempelajari dasar-dasar pemrograman. Dalam konteks pemrograman Python, konsep ini memanfaatkan struktur sintaks yang sederhana dan mudah dipahami sehingga mahasiswa dapat lebih mudah mempelajari cara membuat dan menjalankan program.
#
# Visual Studio Code dapat digunakan sebagai lingkungan pengembangan untuk menulis, menjalankan, serta mengembangkan program Python karena menyediakan berbagai fitur pendukung dalam proses pemrograman. Selain itu, GitHub dapat dimanfaatkan untuk menyimpan dan mengelola kode program secara daring melalui repository sehingga proyek dapat terdokumentasi dan diakses dengan lebih mudah.
#
# Melalui praktikum ini, mahasiswa memperoleh pemahaman dasar mengenai penggunaan Python, Visual Studio Code, serta proses menghubungkan dan mengunggah proyek ke GitHub. Dengan demikian, penggunaan ketiga teknologi tersebut dapat mendukung proses pembelajaran pemrograman secara lebih terstruktur dan efektif.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] GitHub. (2026). About remote repositories. GitHub Docs. https://docs.github.com/en/get-started/git-basics/about-remote-repositories
#
# [2] GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# [3] Microsoft. (2026). Python in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/languages/python
#
# [4] Python Software Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
